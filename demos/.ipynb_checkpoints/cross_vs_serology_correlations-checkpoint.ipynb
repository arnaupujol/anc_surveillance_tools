# %% [markdown]
# # Correlations between Cross-sectional and pregnant women with serological data

# %% [markdown]
# This notebook aims to quantify the correlation between the prevalences in data from cross-sectional and the seropositivity of pregnant women

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib import cm
from spatial_tools import visualise, clustering
from genomic_tools import stats
import scipy.stats as sci_stats
from genomic_tools import utils
import scipy.optimize as optimization
from stat_tools.errors import chi_square, bootstrap_resample
from stat_tools.stats import pearson_cc_boostrap
from stat_tools import tables
from pregmal_pytools import notebook_pytools, temporal_utils, spatial_utils
from time import time

# %%
def linfit_pcc(cross210, mipmon, mipmon_areas, cross_areas, cross_test_type, mip_test_type, cross_bins, \
                           time_width, time_shift, print_sizes = True, \
                           cross_mask = None, mip_mask = None, title = '', \
                           verbose = True, rounding = 3, get_chi2 = False):
    """
    This method outputs the linear fit parameters and the Pearson CC.
    """
    all_cross = np.array([])
    all_mip = np.array([])
    all_cross_err = np.array([])
    all_mip_err = np.array([])
    all_cross_r = []
    all_mip_r = []
    for i in range(len(mipmon_areas)):
        cross_dates, cross_mean, cross_err, cross_means = notebook_pytools.get_cross_prev_bins(cross210, cross_areas[i], \
                                                                                               cross_test_type, cross_bins, \
                                                                 print_sizes = print_sizes, cross_mask = cross_mask, \
                                                                 verbose = verbose, ret_resamples = True)
        #MiPMon
        if mip_mask is None:
            mipmon_mask = mipmon['visit'].notnull()
        else:
            mipmon_mask = mipmon['visit'].notnull()&mip_mask
        mipmon_dates, mipmon_mean, mipmon_err, mipmon_means = notebook_pytools.get_mipmon_prev_bins(mipmon, mipmon_areas[i], \
                                                                                                    mip_test_type, cross_dates, \
                                                                     time_width, time_shift, mask = mipmon_mask, \
                                                                     print_sizes = print_sizes, \
                                                                     verbose = verbose, ret_resamples = True)
        all_cross = np.concatenate((all_cross, cross_mean))
        all_cross_err = np.concatenate((all_cross_err, cross_err))
        all_cross_r.append(cross_means)
        all_mip = np.concatenate((all_mip, mipmon_mean))
        all_mip_err = np.concatenate((all_mip_err, mipmon_err))
        all_mip_r.append(mipmon_means)
    
    all_cross_r, all_mip_r = np.array(all_cross_r), np.array(all_mip_r)
    
    #Linear fits
    mask = (all_cross**2. >= 0)&(all_mip**2. >= 0)&(all_cross_err > 0)&(all_mip_err > 0)
    try:
        p_all = np.polyfit(all_cross[mask], all_mip[mask], 1)
    except:
        p_all = np.nan, np.nan
    #Pearson CC
    pcorr_all = sci_stats.pearsonr(all_cross[mask], all_mip[mask])[0]
    #chi2
    chi2 = chi_square(all_cross[mask], all_cross_err[mask], all_mip[mask], all_mip_err[mask])
    
    #Results from resamples
    fit_vals = []
    pcorrs = []
    nrands = all_cross_r.shape[-1]
    for i in range(nrands):
        mask = all_cross_r[:,:,i]**2. >= 0
        try:
            p_all_r = np.polyfit(all_cross_r[:,:,i][mask], all_mip_r[:,:,i][mask], 1)
        except:
            p_all_r = np.nan, np.nan
        fit_vals.append(p_all_r)
        pcorrs.append(sci_stats.pearsonr(all_cross_r[:,:,i][mask], all_mip_r[:,:,i][mask])[0])
    fit_vals, pcorrs = np.array(fit_vals), np.array(pcorrs)
    #Printing results
    if verbose:
        print("Cross vs MiPMon " + title + ':')
        print("Linear parameter fitting: origin = " + str(p_all[1]) + ", slope = " + str(p_all[0]))
        print("Pearson CC: ", pcorr_all)
        print()
        
    vals_mask = np.invert(np.isnan(fit_vals[:,0]))
    fit_err = np.std(fit_vals[vals_mask], axis = 0)
    pcorr_err = np.std(pcorrs)
    sorted_origin = np.sort(fit_vals[:,1])
    sorted_slope = np.sort(fit_vals[:,0])
    origin_conf_95 = [sorted_origin[int(nrands*.025)], sorted_origin[int(nrands*.975)]]
    origin_conf_68 = [sorted_origin[int(nrands*.16)], sorted_origin[int(nrands*.84)]]
    slope_conf_95 = [sorted_slope[int(nrands*.025)], sorted_slope[int(nrands*.975)]]
    slope_conf_68 = [sorted_slope[int(nrands*.16)], sorted_slope[int(nrands*.84)]]
    sorted_pcorrs = np.sort(pcorrs)
    conf_95 = [sorted_pcorrs[int(nrands*.025)], sorted_pcorrs[int(nrands*.975)]]
    conf_68 = [sorted_pcorrs[int(nrands*.16)], sorted_pcorrs[int(nrands*.84)]]
    fit_mean = np.mean(fit_vals[vals_mask], axis = 0)
    pcorr_mean = np.mean(pcorrs)
    #return p_all, pcorr_all
    
    p_all, fit_err = np.round(p_all, rounding), np.round(fit_err, rounding)
    origin_conf_95, origin_conf_68 = np.round(origin_conf_95,rounding), np.round(origin_conf_68,rounding)
    slope_conf_95, slope_conf_68 = np.round(slope_conf_95,rounding), np.round(slope_conf_68,rounding)
    fit_mean, pcorr_all = np.round(fit_mean, rounding), np.round(pcorr_all, rounding)
    pcorr_err, conf_95 = np.round(pcorr_err, rounding), np.round(conf_95, rounding)
    conf_68, pcorr_mean = np.round(conf_68, rounding), np.round(pcorr_mean, rounding)
    if get_chi2:
        return p_all, fit_err, fit_mean, origin_conf_95, origin_conf_68, slope_conf_95, \
                slope_conf_68, pcorr_all, pcorr_err, conf_95, conf_68, pcorr_mean, chi2
    else:
        return p_all, fit_err, fit_mean, origin_conf_95, origin_conf_68, slope_conf_95, \
                slope_conf_68, pcorr_all, pcorr_err, conf_95, conf_68, pcorr_mean

# %% [markdown]
# # Import data

# %%
mipmon, cross, cross210, antigens = spatial_utils.import_spatial_data()
# Out:
# /home/isglobal.lan/apujol/anaconda3/envs/gen/lib/python3.8/site-packages/geopandas/geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /home/isglobal.lan/apujol/anaconda3/envs/gen/lib/python3.8/site-packages/pregmal_pytools-1.0-py3.8.egg/pregmal_pytools/spatial_utils.py:290: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/isglobal.lan/apujol/anaconda3/envs/gen/lib/python3.8/site-packages/pregmal_pytools-1.0-py3.8.egg/pregmal_pytools/spatial_utils.py:291: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/isglobal.lan/apujol/anaconda3/envs/gen/lib/python3.8/site-packages/pregmal_pytools-1.0-py3.8.egg/pregmal_pytools/spatial_utils.py:292: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/isglobal.lan/apujol/anaconda3/envs/gen/lib/python3.8/site-packages/pregmal_pytools-1.0-py3.8.egg/pregmal_pytools/spatial_utils.py:293: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/isglobal.lan/apujol/anaconda3/envs/gen/lib/python3.8/site-packages/pregmal_pytools-1.0-py3.8.egg/pregmal_pytools/spatial_utils.py:294: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/isglobal.lan/apujol/anaconda3/envs/gen/lib/python3.8/site-packages/pandas/core/generic.py:8870: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)
# /home/isglobal.lan/apujol/anaconda3/envs/gen/lib/python3.8/site-packages/pregmal_pytools-1.0-py3.8.egg/pregmal_pytools/spatial_utils.py:295: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/isglobal.lan/apujol/anaconda3/envs/gen/lib/python3.8/site-packages/pregmal_pytools-1.0-py3.8.egg/pregmal_pytools/spatial_utils.py:296: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/isglobal.lan/apujol/anaconda3/envs/gen/lib/python3.8/site-packages/pregmal_pytools-1.0-py3.8.egg/pregmal_pytools/spatial_utils.py:297: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/isglobal.lan/apujol/anaconda3/envs/gen/lib/python3.8/site-packages/pregmal_pytools-1.0-py3.8.egg/pregmal_pytools/spatial_utils.py:299: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/isglobal.lan/apujol/anaconda3/envs/gen/lib/python3.8/site-packages/pregmal_pytools-1.0-py3.8.egg/pregmal_pytools/spatial_utils.py:300: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/isglobal.lan/apujol/anaconda3/envs/gen/lib/python3.8/site-packages/pregmal_pytools-1.0-py3.8.egg/pregmal_pytools/spatial_utils.py:302: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/isglobal.lan/apujol/anaconda3/envs/gen/lib/python3.8/site-packages/pregmal_pytools-1.0-py3.8.egg/pregmal_pytools/spatial_utils.py:321: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/isglobal.lan/apujol/anaconda3/envs/gen/lib/python3.8/site-packages/pregmal_pytools-1.0-py3.8.egg/pregmal_pytools/spatial_utils.py:322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/isglobal.lan/apujol/anaconda3/envs/gen/lib/python3.8/site-packages/pregmal_pytools-1.0-py3.8.egg/pregmal_pytools/spatial_utils.py:323: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
antigens
# Out:
# ['MSP1',
#  'HSP40',
#  'Etramp',
#  'ACS5',
#  'EBA175',
#  'PfTramp',
#  'GEXP18',
#  'PfRH2',
#  'PfRH5',
#  'P1',
#  'P39',
#  'P8',
#  'PD',
#  'DBL34',
#  'All peptides',
#  'P1+P8']

# %% [markdown]
# ### Define parameters

# %%
#Regions to compare
mipmon_areas = [['Magude-sede'], ['Ilha-Josina'], ['Manhica-Sede']]#, ['Pandjane'], ['3 de Fevereiro']]
cross_areas = [['Magude Sede'], ['Ilha Josina'], ['Manhiça']]#, ['Panjane'], ['Taninga', 'Palmeira', 'Malavele']]

cross_bins = ['2017', '2018', '2019', '2020']

# %%
colors = [cm.turbo((i+1)/float(len(mipmon_areas) + 1)) for i in range(len(mipmon_areas) + 1)]

# %% [markdown]
# ### Define masks

# %%
#Define mask for cross-sectional PCRs due to sampling issues
cross_pcr_mask = cross210['pospcr'].notnull()
cross_pcr_mask[(cross210['visdate'] < '2018')&(cross210['area'] == 'Manhiça')] = False
#cross_pcr_mask[(cross210['visdate'] > '2018')&(cross210['visdate'] < '2019')&(cross210['area'] == 'Magude Sede')] = False

#Define masks for MiPMon data
mipmon_pn = mipmon['visit'] == 'PN'
mipmon_pg = mipmon_pn&(mipmon['gestnum'] == 1)
mipmon_mg = mipmon_pn&(mipmon['gestnum'] > 1)
mipmon_hiv_pos = mipmon_pn&(mipmon['hiv'] == 'HIV+')
mipmon_hiv_neg = mipmon_pn&(mipmon['hiv'] == 'HIV-')
mipmon_pg_hiv_pos = mipmon_pg&mipmon_hiv_pos
mipmon_pg_hiv_neg = mipmon_pg&mipmon_hiv_neg

mipmon_selection = {
    'All ANC visits' : mipmon_pn,
    'Primigravidae' : mipmon_pg,
    'Multigravidae' : mipmon_mg,
    'HIV+' : mipmon_hiv_pos,
    'HIV-' : mipmon_hiv_neg,
    #'PG HIV+' : mipmon_pg_hiv_pos,
    'Primigravid HIV-' : mipmon_pg_hiv_neg,
}

# %% [markdown]
# ### Results

# %%
fontsize = 18

# %%
#Define test and time binning comparison
cross_test_type = 'pcr'
cross_mask = cross_pcr_mask
time_width = 90
time_shift = 0
ant = 'DBL34'
mip_test_type = 'FMM_' + ant
i = 'All ANC visits'
p, pcorr = notebook_pytools.scatter_linfit_pcc(cross210, mipmon, mipmon_areas, cross_areas, \
                                        cross_test_type, mip_test_type, cross_bins, \
                        time_width = time_width, time_shift = time_shift, print_sizes = False, \
                           cross_mask = cross_mask, mip_mask = mipmon_selection[i], \
                                            title = i, verbose = False, show = False, \
                                            show_identity = False, fontsize = fontsize, \
                                              legend = False)
# Out:
# Cross vs MiPMon All ANC visits:
# Linear parameter fitting: origin = 0.20308229342060957, slope = 1.0996859252335411
# Pearson CC:  0.8816394864668425

# %%
#Define test and time binning comparison
cross_test_type = 'pcr'
cross_mask = cross_pcr_mask
time_width = 90
time_shift = 0

start = time()
results_serology = {}
for ant in antigens:
    print("-----", ant, "-----")
    mip_test_type = 'FMM_' + ant
    
    fit_params = [{},{}]
    fit_errs = [{},{}]
    slope_95 = {}
    slope_68 = {}
    origin_95 = {}
    origin_68 = {}
    pearsonCCs = {}
    pearsonCC_errs = {}
    pearsonCC_95 = {}
    pearsonCC_68 = {}
    
    for i in mipmon_selection:
        #Plotting scatter
        p, pcorr = notebook_pytools.scatter_linfit_pcc(cross210, mipmon, mipmon_areas, cross_areas, \
                                        cross_test_type, mip_test_type, cross_bins, \
                        time_width = time_width, time_shift = time_shift, print_sizes = False, \
                           cross_mask = cross_mask, mip_mask = mipmon_selection[i], \
                                            title = i, verbose = False, show = False, \
                                                      show_identity = False)
        
        #Calculating statistics
        p_all, fit_err, fit_mean, origin_95[i], origin_68[i], slope_95[i], slope_68[i], \
        pearsonCCs[i], pearsonCC_errs[i], pearsonCC_95[i], pearsonCC_68[i], pcorr_mean = linfit_pcc(cross210, \
                                                            mipmon, mipmon_areas, cross_areas, \
                                                            cross_test_type, mip_test_type, cross_bins, \
                                                time_width = time_width, time_shift = 0, print_sizes = False, \
                                                   cross_mask = cross_mask, mip_mask = mipmon_selection[i], \
                                                            title = i, verbose = False, rounding = 2)
        fit_params[0][i], fit_params[1][i] = p_all
        fit_errs[0][i], fit_errs[1][i] = fit_err
    
    results_serology[ant] = pd.DataFrame({'Slope': fit_params[0], \
                          #'Slope error': fit_errs[0], \
                          'Slope 95CI': slope_95, \
                            #'Slope 68CI': slope_68, \
                          'Origin': fit_params[1], \
                          #'Origin error': fit_errs[1], \
                          'Origin 95CI': origin_95, \
                          #'Origin 68CI': origin_68, \
                          'PCC' : pearsonCCs, \
                          #'PCC error' : pearsonCC_errs, \
                          'PCC 95CI' : pearsonCC_95,\
                          #'PCC 68CI' : pearsonCC_68
                         })
end = time()
print('Time taken ', end-start,' seconds (', int((end-start)/60), 'minutes)')
# Out:
# ----- MSP1 -----
# Cross vs MiPMon All ANC visits:
# Linear parameter fitting: origin = 0.4527364938257818, slope = 1.046028097534173
# Pearson CC:  0.791461218296744
#
# Cross vs MiPMon Primigravidae:
# Linear parameter fitting: origin = 0.43107282486465176, slope = 1.1308054021181446
# Pearson CC:  0.7983696843739193
#
# Cross vs MiPMon Multigravidae:
# Linear parameter fitting: origin = 0.46289250721166086, slope = 1.0088089136197633
# Pearson CC:  0.7786164365877639
#
# Cross vs MiPMon HIV+:
# Linear parameter fitting: origin = 0.3923944511614647, slope = 1.1287947598905688
# Pearson CC:  0.8701291955563218
#
# Cross vs MiPMon HIV-:
# Linear parameter fitting: origin = 0.4759418814984392, slope = 0.9894476029917562
# Pearson CC:  0.7381847899252313
#
# Cross vs MiPMon Primigravid HIV-:
# Linear parameter fitting: origin = 0.4256586722958623, slope = 1.2136141321214842
# Pearson CC:  0.8344222224196327
#
# ----- HSP40 -----
# Cross vs MiPMon All ANC visits:
# Linear parameter fitting: origin = 0.16791861383601636, slope = 0.8531305299401766
# Pearson CC:  0.731795549233412
#
# Cross vs MiPMon Primigravidae:
# Linear parameter fitting: origin = 0.13071012881786503, slope = 1.202042848625129
# Pearson CC:  0.8821886376087082
#
# Cross vs MiPMon Multigravidae:
# Linear parameter fitting: origin = 0.18551744926184272, slope = 0.7083361438193649
# Pearson CC:  0.6062292310681692
#
# Cross vs MiPMon HIV+:
# Linear parameter fitting: origin = 0.19655124039883964, slope = 0.34375206321275004
# Pearson CC:  0.5403195316524436
#
# Cross vs MiPMon HIV-:
# Linear parameter fitting: origin = 0.1543296206476364, slope = 1.0353555412269806
# Pearson CC:  0.7618047227226445
#
# Cross vs MiPMon Primigravid HIV-:
# Linear parameter fitting: origin = 0.11778494158249271, slope = 1.352903235146784
# Pearson CC:  0.8770113596328538
#
# ----- Etramp -----
# Cross vs MiPMon All ANC visits:
# Linear parameter fitting: origin = 0.15999717385068932, slope = 0.8267905446144544
# Pearson CC:  0.8074708815308784
#
# Cross vs MiPMon Primigravidae:
# Linear parameter fitting: origin = 0.14980674484864206, slope = 1.0547792207079774
# Pearson CC:  0.9048444391108765
#
# Cross vs MiPMon Multigravidae:
# Linear parameter fitting: origin = 0.1634599464862496, slope = 0.7374165864444988
# Pearson CC:  0.7305748374216737
#
# Cross vs MiPMon HIV+:
# Linear parameter fitting: origin = 0.16013667492004574, slope = 0.37628669737372583
# Pearson CC:  0.7434221946057367
#
# Cross vs MiPMon HIV-:
# Linear parameter fitting: origin = 0.15851809134364994, slope = 0.9748083428625814
# Pearson CC:  0.7929575462672751
#
# Cross vs MiPMon Primigravid HIV-:
# Linear parameter fitting: origin = 0.14601907314970056, slope = 1.1554773724420317
# Pearson CC:  0.8724349011452032
#
# ----- ACS5 -----
# Cross vs MiPMon All ANC visits:
# Linear parameter fitting: origin = 0.25748556237213666, slope = 1.2441869544398236
# Pearson CC:  0.7760685891692083
#
# Cross vs MiPMon Primigravidae:
# Linear parameter fitting: origin = 0.24715367433097546, slope = 0.9987548793061369
# Pearson CC:  0.6838313876837039
# /home/isglobal.lan/apujol/anaconda3/envs/gen/lib/python3.8/site-packages/pregmal_pytools-1.0-py3.8.egg/pregmal_pytools/notebook_pytools.py:168: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Cross vs MiPMon Multigravidae:
# Linear parameter fitting: origin = 0.26111123258869245, slope = 1.3508264372229941
# Pearson CC:  0.8023798706620769
#
# Cross vs MiPMon HIV+:
# Linear parameter fitting: origin = 0.22113624406962942, slope = 1.0766866883207766
# Pearson CC:  0.7851752932201852
#
# Cross vs MiPMon HIV-:
# Linear parameter fitting: origin = 0.26710259135248854, slope = 1.285678857037154
# Pearson CC:  0.7597531681440255
#
# Cross vs MiPMon Primigravid HIV-:
# Linear parameter fitting: origin = 0.26019938914809176, slope = 0.9673063615519067
# Pearson CC:  0.6622637709612071
#
# ----- EBA175 -----
# Cross vs MiPMon All ANC visits:
# Linear parameter fitting: origin = 0.3084313712276343, slope = 0.9119254918509335
# Pearson CC:  0.8397217804118177
#
# Cross vs MiPMon Primigravidae:
# Linear parameter fitting: origin = 0.287399612525994, slope = 0.7957719781048159
# Pearson CC:  0.7367556216046014
#
# Cross vs MiPMon Multigravidae:
# Linear parameter fitting: origin = 0.31878489021457124, slope = 0.9559675371524784
# Pearson CC:  0.8604305070986036
#
# Cross vs MiPMon HIV+:
# Linear parameter fitting: origin = 0.25258660952147444, slope = 0.8684200818489202
# Pearson CC:  0.8451934103165716
#
# Cross vs MiPMon HIV-:
# Linear parameter fitting: origin = 0.3315400108487479, slope = 0.9081275930121029
# Pearson CC:  0.8317361477444124
#
# Cross vs MiPMon Primigravid HIV-:
# Linear parameter fitting: origin = 0.2982422872832503, slope = 0.8552071059213138
# Pearson CC:  0.7697777719653826
#
# ----- PfTramp -----
# Cross vs MiPMon All ANC visits:
# Linear parameter fitting: origin = 0.19028436282712982, slope = 0.5360704139685436
# Pearson CC:  0.6999921834344154
#
# Cross vs MiPMon Primigravidae:
# Linear parameter fitting: origin = 0.21140441385937897, slope = 0.8644206296470189
# Pearson CC:  0.7404739772439094
#
# Cross vs MiPMon Multigravidae:
# Linear parameter fitting: origin = 0.18399615386048712, slope = 0.3885291971239073
# Pearson CC:  0.6124480016841664
#
# Cross vs MiPMon HIV+:
# Linear parameter fitting: origin = 0.13233944236088874, slope = 0.37791313803674725
# Pearson CC:  0.5853536714785751
#
# Cross vs MiPMon HIV-:
# Linear parameter fitting: origin = 0.21214598758995393, slope = 0.5629575407501854
# Pearson CC:  0.5695427660328833
#
# Cross vs MiPMon Primigravid HIV-:
# Linear parameter fitting: origin = 0.20483068037278906, slope = 1.0749998879350464
# Pearson CC:  0.7685892393998652
#
# ----- GEXP18 -----
# Cross vs MiPMon All ANC visits:
# Linear parameter fitting: origin = 0.047393032228260065, slope = 0.5622149273738857
# Pearson CC:  0.939499457494212
#
# Cross vs MiPMon Primigravidae:
# Linear parameter fitting: origin = 0.0547748462915365, slope = 0.8971854063647272
# Pearson CC:  0.8910105697741822
#
# Cross vs MiPMon Multigravidae:
# Linear parameter fitting: origin = 0.0433726211012842, slope = 0.42702473372942845
# Pearson CC:  0.8501909160058687
#
# Cross vs MiPMon HIV+:
# Linear parameter fitting: origin = 0.07892650719075713, slope = 0.3506980233406182
# Pearson CC:  0.4965671427790432
#
# Cross vs MiPMon HIV-:
# Linear parameter fitting: origin = 0.03120517860116545, slope = 0.6410020391144328
# Pearson CC:  0.9701025590842738
#
# Cross vs MiPMon Primigravid HIV-:
# Linear parameter fitting: origin = 0.036648149102283235, slope = 0.9995940297250101
# Pearson CC:  0.8878017178463484
#
# ----- PfRH2 -----
# Cross vs MiPMon All ANC visits:
# Linear parameter fitting: origin = 0.10162994971374315, slope = 0.7059500423153706
# Pearson CC:  0.9298094418694204
#
# Cross vs MiPMon Primigravidae:
# Linear parameter fitting: origin = 0.1044763475819808, slope = 0.47890173159000676
# Pearson CC:  0.7459408407081015
#
# Cross vs MiPMon Multigravidae:
# Linear parameter fitting: origin = 0.10051934820813485, slope = 0.8049880309061253
# Pearson CC:  0.9409118732392645
#
# Cross vs MiPMon HIV+:
# Linear parameter fitting: origin = 0.13816369983295607, slope = 0.6260138887559251
# Pearson CC:  0.8932870837366267
#
# Cross vs MiPMon HIV-:
# Linear parameter fitting: origin = 0.08735572483594746, slope = 0.7418528198909168
# Pearson CC:  0.9368669786955348
#
# Cross vs MiPMon Primigravid HIV-:
# Linear parameter fitting: origin = 0.09147399636245086, slope = 0.6288848220483421
# Pearson CC:  0.7800959459022629
#
# ----- PfRH5 -----
# Cross vs MiPMon All ANC visits:
# Linear parameter fitting: origin = 0.10870522636436623, slope = 1.016230548295454
# Pearson CC:  0.9110895070568064
#
# Cross vs MiPMon Primigravidae:
# Linear parameter fitting: origin = 0.17108227970368364, slope = 0.5580093360406744
# Pearson CC:  0.6666620989462996
#
# Cross vs MiPMon Multigravidae:
# Linear parameter fitting: origin = 0.082571621465531, slope = 1.2084580702593433
# Pearson CC:  0.9277147280025768
#
# Cross vs MiPMon HIV+:
# Linear parameter fitting: origin = 0.08511896128316213, slope = 1.0814151016799132
# Pearson CC:  0.9356141141618225
#
# Cross vs MiPMon HIV-:
# Linear parameter fitting: origin = 0.11378092041332416, slope = 0.983086100054243
# Pearson CC:  0.8865956834095053
#
# Cross vs MiPMon Primigravid HIV-:
# Linear parameter fitting: origin = 0.1730378636024835, slope = 0.5835572127323543
# Pearson CC:  0.6006373723213254
#
# ----- P1 -----
# Cross vs MiPMon All ANC visits:
# Linear parameter fitting: origin = 0.08107993351194365, slope = 0.27520380717853243
# Pearson CC:  0.8322397935665344
#
# Cross vs MiPMon Primigravidae:
# Linear parameter fitting: origin = 0.06137196456487739, slope = 0.4577314840261637
# Pearson CC:  0.8096087794148904
#
# Cross vs MiPMon Multigravidae:
# Linear parameter fitting: origin = 0.09034995200536418, slope = 0.1966625567035437
# Pearson CC:  0.5459721844075057
#
# Cross vs MiPMon HIV+:
# Linear parameter fitting: origin = 0.15563929938486912, slope = 0.21128247950015008
# Pearson CC:  0.4769316515224632
#
# Cross vs MiPMon HIV-:
# Linear parameter fitting: origin = 0.050022079808062614, slope = 0.30815566456824645
# Pearson CC:  0.8198060890324476
#
# Cross vs MiPMon Primigravid HIV-:
# Linear parameter fitting: origin = 0.03101407172816293, slope = 0.5238919072123043
# Pearson CC:  0.9249657173636927
#
# ----- P39 -----
# Cross vs MiPMon All ANC visits:
# Linear parameter fitting: origin = 0.07750779858892551, slope = 0.3662735728810988
# Pearson CC:  0.8747086607075389
#
# Cross vs MiPMon Primigravidae:
# Linear parameter fitting: origin = 0.07150043448653083, slope = 0.5608802439229229
# Pearson CC:  0.9225115785266913
#
# Cross vs MiPMon Multigravidae:
# Linear parameter fitting: origin = 0.07846139136350806, slope = 0.28967348135392373
# Pearson CC:  0.7562656403716244
#
# Cross vs MiPMon HIV+:
# Linear parameter fitting: origin = 0.0908397875480942, slope = 0.47736188609861374
# Pearson CC:  0.8288123343147665
#
# Cross vs MiPMon HIV-:
# Linear parameter fitting: origin = 0.0733933530020233, slope = 0.32998064049529136
# Pearson CC:  0.8440450020420482
#
# Cross vs MiPMon Primigravid HIV-:
# Linear parameter fitting: origin = 0.06891568808182519, slope = 0.5639672726088427
# Pearson CC:  0.8906543875246431
#
# ----- P8 -----
# Cross vs MiPMon All ANC visits:
# Linear parameter fitting: origin = 0.04861491584775349, slope = 0.4483230858395679
# Pearson CC:  0.8875850927592239
#
# Cross vs MiPMon Primigravidae:
# Linear parameter fitting: origin = 0.04903994160400094, slope = 0.3339491738428741
# Pearson CC:  0.8134979794882354
#
# Cross vs MiPMon Multigravidae:
# Linear parameter fitting: origin = 0.04870914880574849, slope = 0.49689131141102516
# Pearson CC:  0.8843685764883458
#
# Cross vs MiPMon HIV+:
# Linear parameter fitting: origin = 0.07729998289397831, slope = 0.2606480254772123
# Pearson CC:  0.506415889469756
#
# Cross vs MiPMon HIV-:
# Linear parameter fitting: origin = 0.03401121545133037, slope = 0.515874526048613
# Pearson CC:  0.9193845261113285
#
# Cross vs MiPMon Primigravid HIV-:
# Linear parameter fitting: origin = 0.03605947259157639, slope = 0.44040084037527566
# Pearson CC:  0.8889693518735509
#
# ----- PD -----
# Cross vs MiPMon All ANC visits:
# Linear parameter fitting: origin = 0.08285007006801626, slope = 0.37178098655139763
# Pearson CC:  0.9041456341435472
#
# Cross vs MiPMon Primigravidae:
# Linear parameter fitting: origin = 0.08758833225861401, slope = 0.40820049985210827
# Pearson CC:  0.7179550361666319
#
# Cross vs MiPMon Multigravidae:
# Linear parameter fitting: origin = 0.08297630868386827, slope = 0.3566184499980815
# Pearson CC:  0.7460072147132061
#
# Cross vs MiPMon HIV+:
# Linear parameter fitting: origin = 0.11677190285034986, slope = 0.2992559529161989
# Pearson CC:  0.7221416993569618
#
# Cross vs MiPMon HIV-:
# Linear parameter fitting: origin = 0.07120650360827038, slope = 0.4035813948222989
# Pearson CC:  0.9078374741660051
#
# Cross vs MiPMon Primigravid HIV-:
# Linear parameter fitting: origin = 0.07682121941084298, slope = 0.43095730956109846
# Pearson CC:  0.7758139869386316
#
# ----- DBL34 -----
# Cross vs MiPMon All ANC visits:
# Linear parameter fitting: origin = 0.20308229342060957, slope = 1.0996859252335411
# Pearson CC:  0.8816394864668425
#
# Cross vs MiPMon Primigravidae:
# Linear parameter fitting: origin = 0.0907752486302299, slope = 0.6088799338024365
# Pearson CC:  0.8512720555652044
#
# Cross vs MiPMon Multigravidae:
# Linear parameter fitting: origin = 0.24972193267479553, slope = 1.3126103466178065
# Pearson CC:  0.8566309455278398
#
# Cross vs MiPMon HIV+:
# Linear parameter fitting: origin = 0.2713448874289891, slope = 0.7366428733913388
# Pearson CC:  0.7916953093362853
#
# Cross vs MiPMon HIV-:
# Linear parameter fitting: origin = 0.1700106383861258, slope = 1.235684735342107
# Pearson CC:  0.8905453397639664
#
# Cross vs MiPMon Primigravid HIV-:
# Linear parameter fitting: origin = 0.07507257706358447, slope = 0.7677857014595417
# Pearson CC:  0.9008600045398651
#
# ----- All peptides -----
# Cross vs MiPMon All ANC visits:
# Linear parameter fitting: origin = 0.19739482692154506, slope = 0.575377313975391
# Pearson CC:  0.8344124693800685
#
# Cross vs MiPMon Primigravidae:
# Linear parameter fitting: origin = 0.17566518848911802, slope = 0.5578870173646032
# Pearson CC:  0.7623998320229535
#
# Cross vs MiPMon Multigravidae:
# Linear parameter fitting: origin = 0.2080238458164898, slope = 0.5898610374184767
# Pearson CC:  0.6856033742090736
#
# Cross vs MiPMon HIV+:
# Linear parameter fitting: origin = 0.283250082759973, slope = 0.2908761435065417
# Pearson CC:  0.5751554928219195
#
# Cross vs MiPMon HIV-:
# Linear parameter fitting: origin = 0.16296293409598817, slope = 0.6897539576998943
# Pearson CC:  0.850406459270622
#
# Cross vs MiPMon Primigravid HIV-:
# Linear parameter fitting: origin = 0.147051783524747, slope = 0.6743566839517229
# Pearson CC:  0.8439090348869718
#
# ----- P1+P8 -----
# Cross vs MiPMon All ANC visits:
# Linear parameter fitting: origin = 0.11046063030498336, slope = 0.43421904456570476
# Pearson CC:  0.8568384470589706
#
# Cross vs MiPMon Primigravidae:
# Linear parameter fitting: origin = 0.09500473437472406, slope = 0.49898101404610945
# Pearson CC:  0.8566326470784725
#
# Cross vs MiPMon Multigravidae:
# Linear parameter fitting: origin = 0.11828150477492513, slope = 0.4065142899978936
# Pearson CC:  0.7603653842480573
#
# Cross vs MiPMon HIV+:
# Linear parameter fitting: origin = 0.20278310696440774, slope = 0.17552695300711227
# Pearson CC:  0.30612792716388904
#
# Cross vs MiPMon HIV-:
# Linear parameter fitting: origin = 0.07099301097271919, slope = 0.5401704453793982
# Pearson CC:  0.8992382031525336
#
# Cross vs MiPMon Primigravid HIV-:
# Linear parameter fitting: origin = 0.06304129408442564, slope = 0.590450304480077
# Pearson CC:  0.9374261668091858
#
# Time taken  201.3608682155609  seconds ( 3 minutes)

# %%
all_serology_results = pd.DataFrame({})
for ant in antigens:
    for s in mipmon_selection:
        all_serology_results[ant + ' ' + s] = results_serology[ant].T[s]

# %% [markdown]
# ### Visualising the results

# %%
fontsize = 18

# %%
pcr_results = pd.DataFrame({
    'PCC' : {'All prenatal' : .941, \
             'Primigravidae' : .919, \
            'Multigravidae' : .947, \
            'HIV+' : .879, \
            'HIV-' : .952, \
            'Primigravid HIV-' : .861}, 
    'PCC 95CI' : {'All prenatal' : [.698, .985], \
                  'Primigravidae' : [.527, .979], \
                 'Multigravidae' : [.636, .988], \
                 'HIV+' : [.292, .977], \
                 'HIV-' : [.698, .986], \
                 'Primigravid HIV-' : [.453, .972]}
})
rdt_results = pd.DataFrame({
    'PCC' : {'All prenatal' : .841, \
             'Primigravidae' : .672, \
            'Multigravidae' : .608, \
            'HIV+' : .960, \
            'HIV-' : .760, \
            'Primigravid HIV-' : .655}, 
    'PCC 95CI' : {'All prenatal' : [.307, .952], \
                  'Primigravidae' : [.093, .939], \
                 'Multigravidae' : [-.121, .936], \
                 'HIV+' : [.049, .976], \
                 'HIV-' : [.223, .937], \
                 'Primigravid HIV-' : [.112, .935]}
})
parasitology_results = [pcr_results, rdt_results]

# %%
plt.figure(figsize = [16,5])
colors_a = [cm.turbo(i/len(antigens)) for i in range(len(antigens))]
colors_p = ['k', 'tab:grey']
labels_p = ['qPCR', 'RDT']

for i, t in enumerate(parasitology_results):
    x = np.arange(len(t)) -.05 - .05*i
    y = t['PCC']
    yerr = np.array([list(i) for i in t['PCC 95CI']]).T 
    yerr[0] = y - yerr[0]
    yerr[1] = yerr[1] - y
    plt.errorbar(x, y, yerr, marker = 'o', label = labels_p[i], color = colors_p[i], linestyle = '')
    
for i, ant in enumerate(antigens):
    x = np.arange(len(results_serology[ant])) + .05*i
    y = results_serology[ant]['PCC']
    yerr = np.array([list(i) for i in results_serology[ant]['PCC 95CI']]).T 
    yerr[0] = y - yerr[0]
    yerr[1] = yerr[1] - y
    plt.errorbar(x, y, yerr, marker = 'o', label = ant, color = colors_a[i], linestyle = '')
plt.xticks(ticks = x-.5, labels = list(results_serology[ant].index), fontsize = fontsize)
plt.yticks(fontsize = fontsize)
plt.legend(ncol = 6, fontsize = fontsize, framealpha = 1)
plt.ylabel('Pearson CC', fontsize = fontsize)
plt.ylim(-.2,1)
plt.show()

# %%
results_serology[ant]
# Out:
#                   Slope     Slope 95CI  Origin   Origin 95CI   PCC  \
# All ANC visits     0.43   [0.13, 0.86]    0.11  [0.08, 0.14]  0.86
# Primigravidae      0.50  [-0.03, 1.23]    0.10  [0.05, 0.15]  0.86
# Multigravidae      0.41   [0.08, 0.94]    0.12  [0.08, 0.16]  0.76
# HIV+               0.18  [-0.48, 0.84]    0.20  [0.14, 0.27]  0.31
# HIV-               0.54     [0.2, 1.2]    0.07  [0.04, 0.11]  0.90
# Primigravid HIV-   0.59   [0.05, 1.39]    0.06  [0.02, 0.12]  0.94
#
#                        PCC 95CI
# All ANC visits     [0.33, 0.93]
# Primigravidae     [-0.06, 0.93]
# Multigravidae      [0.16, 0.89]
# HIV+              [-0.49, 0.75]
# HIV-               [0.41, 0.96]
# Primigravid HIV-   [0.13, 0.96]
