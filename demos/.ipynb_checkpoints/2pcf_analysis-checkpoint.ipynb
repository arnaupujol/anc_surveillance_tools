# %% [markdown]
# # 2-Point Correlation Function (2PCF) analysis

# %% [markdown]
# In this notebook we perform the main analysis using 2PCFs in pregnant women at ANC visits and children from cross-sectional surveys.
#
# Main analysis:
#
# 1- Spatial binning and ranges of 2PCF will be chosen according to the sample size and distribution of samples, looking for the balance between having fine spatial granularity and having small error bars to identify the spatial patterns. Exploratory analysis with the data will be done to decide these parameters
#
# 2- 2PCF measurements: 2PCF statistics will be obtained for the three cross-sectional data separately, and the same measurements will be done for the different populations of pregnant women (all first ANC visits, primigravid women, multigravid women, HIV+ women and HIV- women). Data from pregnant women will be selected around the dates of the cross-sectional surveys. The temporal window for the selection of pregnant women will be chosen with two purposes:
#
#     a) To compare the results with similar sample sizes, selecting the temporal windows to obtain a similar sample size than the data from children
#
#     b) To assess the impact of using a larger time window in pregnant women to increase the precision of the measurements with respect to cross-sectional surveys
#
# 3- Consistency analysis: statistics will be obtained comparing the 2PCF measurement in children with the different populations of pregnant women. Values larger than a ² threshold will be considered as different results between the two populations. Alternatively, t-test statistics will be used for the same purpose (they should give the same conclusions).
#
# 4- Significance analysis: a t-test will be used to measure the statistical significance of the clustering signal of the different populations by measuring the deviation of the 2PCFs from zero. A table will be created describing the p-values of each population and year to identify the most significant clustering structures found.
#
# 5- Potential complementary descriptive analysis (TBD): we will measure the number of samples as a function of the geographical distance from the closest health centre from the three centres of the MiPMon project. This will be done for the different populations of pregnant women in order to identify possible differences in the geographic distribution of them. The same will be done for children 2-10 to compare how differently they are distributed compared to pregnant women. This will potentially help to refine the interpretation of the 2PCF results and the different statistical power for the different populations and scales.

# %% [markdown]
# ## Importing modules and functions

# %%
import numpy as np
import pandas as pd
import geopandas
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib import cm
from spatial_tools import clustering, visualise
from stat_tools import errors
import contextily as ctx
from pregmal_pytools import spatial_utils

# %% [markdown]
# ## Importing data

# %%
#mipmon, cross, cross210, antigens = spatial_utils.import_spatial_data()
# Out:
# /home/isglobal.lan/apujol/anaconda3/envs/gen/lib/python3.8/site-packages/geopandas/geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_460099/3763902937.py in <module>
# ----> 1 mipmon, cross, cross210, antigens = spatial_utils.import_spatial_data()
#
# ~/anaconda3/envs/gen/lib/python3.8/site-packages/pregmal_pytools-1.0-py3.8.egg/pregmal_pytools/spatial_utils.py in import_spatial_data(data_path, cross_name, mipmon_name, serology_name, intermediate_val, excluded_antigens, study_year)
# ...

# %%
mipmon, cross, cross210 = spatial_utils.import_spatial_data(serology_name = None)
# Out:
# /home/isglobal.lan/apujol/anaconda3/envs/gen/lib/python3.8/site-packages/geopandas/geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /home/isglobal.lan/apujol/anaconda3/envs/gen/lib/python3.8/site-packages/pregmal_pytools-1.0-py3.8.egg/pregmal_pytools/spatial_utils.py:283: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cross['pospcr'][cross['pospcr'] == 'Negative'] = 0.
# ...

# %% [markdown]
# ## Define masks and other definitions

# %%
#MiPMon masks
has_geo_mip = mipmon['latitude'].notnull()&mipmon['longitude'].notnull()
has_pcr_mip = mipmon['pcrpos'].notnull()&has_geo_mip
mip_pcrpos = mipmon['pcrpos'] == 1
mip_pcrneg = mipmon['pcrpos'] == 0
mip_rdtpos = mipmon['density'] >= 100
mip_rdtneg = mipmon['density'] < 100
prenatal = (mipmon['visit'] == 'PN')&has_pcr_mip

#Define masks for MiPMon data
mipmon_pn = prenatal&has_pcr_mip
mipmon_pg = mipmon_pn&(mipmon['gestnum'] == 1)
mipmon_sg = mipmon_pn&(mipmon['gestnum'] == 2)
mipmon_12g = mipmon_pn&(mipmon['gestnum'] <= 2)
mipmon_mg = mipmon_pn&(mipmon['gestnum'] > 1)
mipmon_3g = mipmon_pn&(mipmon['gestnum'] > 2)
mipmon_hiv_pos = mipmon_pn&(mipmon['hiv'] == 'HIV+')
mipmon_hiv_neg = mipmon_pn&(mipmon['hiv'] == 'HIV-')
mipmon_pg_hiv_pos = mipmon_pg&mipmon_hiv_pos
mipmon_pg_hiv_neg = mipmon_pg&mipmon_hiv_neg

mipmon_selection = {
    'ANC (all)' : mipmon_pn,
    'ANC (PG)' : mipmon_pg,
    #'Secundigravid' : mipmon_sg,
    #'1-2gravid' : mipmon_12g,
    #'>2gravid' : mipmon_3g,
    'ANC (MG)' : mipmon_mg,
    'ANC (HIV+)' : mipmon_hiv_pos,
    'ANC (HIV-)' : mipmon_hiv_neg,
    #'PG HIV+' : mipmon_pg_hiv_pos,
    'ANC (PG HIV-)' : mipmon_pg_hiv_neg,
}

#Cross masks
cross210_area_mask = (cross210['area'] == 'Magude Sede')|(cross210['area'] == 'Manhiça')|(cross210['area'] == 'Ilha Josina')
cross210_area_mask = cross210_area_mask | (cross210['area'] == 'Taninga')|(cross210['area'] == 'Panjane')
cross210_area_mask = cross210_area_mask |(cross210['area'] == 'Palmeira')
cross210_area_mask = cross210_area_mask | (cross210['area'] == 'Maragra')|(cross210['area'] == 'Malavele')
has_geo_cross = cross['lat'].notnull()&cross['lng'].notnull()
has_pcr_cross = cross['pospcr'].notnull()&has_geo_cross
has_rdt_cross = cross['rdt'].notnull()&has_geo_cross
cross_pcrpos = cross['pospcr'] == 1
cross_pcrneg = cross['pospcr'] == 0
cross_rdtpos = cross['rdt'] == 1
cross_rdtneg = cross['rdt'] == 0

has_geo_cross210 = cross210['lat'].notnull()&cross210['lng'].notnull()
has_pcr_cross210 = cross210['pospcr'].notnull()&has_geo_cross210
has_rdt_cross210 = cross210['rdt'].notnull()&has_geo_cross210
cross210_pcrpos = cross210['pospcr'] == 1
cross210_pcrneg = cross210['pospcr'] == 0
cross210_rdtpos = cross210['rdt'] == 1
cross210_rdtneg = cross210['rdt'] == 0


#Colour palette for MiPMon selections
colors_mipmon = [cm.turbo((i+1)/float(len(mipmon_selection) + 1)) for i in range(len(mipmon_selection) + 1)]

#years = [2017, 2018, 2019]
years = [1, 2, 3]

# %%
ymask = cross210['year']>0
np.sum((cross210['area'] == 'Malavele')&ymask)
# Out:
# 87

# %% [markdown]
# # Analysis

# %% [markdown]
# ## Defining Spatial binning and ranges of 2PCF
#
# Spatial binning and ranges of 2PCF will be chosen according to the sample size and distribution of samples, looking for the balance between having fine spatial granularity and having small error bars to identify the spatial patterns. Exploratory analysis with the data will be done to decide these parameters

# %% [markdown]
# We will use the cross-sectional data as the reference to define these parameters, since their sample sizes are limited by the date of the surveys and only one data selection (children 2-10 years old) will be used and taken as the reference for the comparison with ANC data.

# %% [markdown]
# ### Histograms of distances in MiPMon and cross-sectional positive cases

# %%
for y in years:
    mip_mask = mipmon['year'] == y
    c210_mask = cross210['year'] == y
    #Defining positions and weights to get distances
    x1 = np.array(cross210[c210_mask&has_pcr_cross210&cross210_pcrpos]['lng'])
    y1 = np.array(cross210[c210_mask&has_pcr_cross210&cross210_pcrpos]['lat'])
    w1 = np.array(cross210[c210_mask&has_pcr_cross210&cross210_pcrpos]['weight'])
    w2 = np.array(cross210[c210_mask&has_pcr_cross210&cross210_pcrpos]['weight'])
    #Calculating all distances within cross-sectional surveys
    distances_cross, weights_cross = all_dist_cross = clustering.all_distances(x1, y1, w1 = w1, w2 = w2)
    
    #Defining positions and weights to get distances
    x1 = np.array(mipmon[mip_mask&prenatal&mip_pcrpos]['longitude'])
    y1 = np.array(mipmon[mip_mask&prenatal&mip_pcrpos]['latitude'])
    #Calculating all distances within 1st ANC visits
    distances_mip = all_dist_cross = clustering.all_distances(x1, y1)
    
    plt.hist(distances_cross, 20, range = [0,100], label = 'Cross-sectionals', alpha = .5)
    plt.hist(distances_mip, 20, range = [0,100], label = 'ANC visits', alpha = .5)
    plt.title('Year ' + str(y))
    plt.xlabel('Distance (Km)')
    plt.ylabel('Number of pairs')
    plt.yscale('log')
    plt.legend()
    plt.show()

# %% [markdown]
# We see that ANC of positive data pairs (the numberator of the 2PCFs) drop at 60Km, so this will be the maximum distances to look at.

# %%
#Number of bins to explore
bin_values = [4, 8, 10, 12, 16]
colors_bins = [cm.turbo((i+1)/float(len(bin_values) + 1)) for i in range(len(bin_values) + 1)]
#Spatial range of scale in Km
ranges = [.0,60.]
#Number of random realisations
nrands = 50

for y in years:
    #Select data from the year
    c210_mask = cross210['year'] == y
    #Define input data vectors for the 2PCF call
    x1 = np.array(cross210[c210_mask&has_pcr_cross210&cross210_pcrpos]['lng'])
    y1 = np.array(cross210[c210_mask&has_pcr_cross210&cross210_pcrpos]['lat'])
    x2 = np.array(cross210[c210_mask&has_pcr_cross210]['lng'])
    y2 = np.array(cross210[c210_mask&has_pcr_cross210]['lat'])
    w1 = np.array(cross210[c210_mask&has_pcr_cross210&cross210_pcrpos]['weight'])
    w2 = np.array(cross210[c210_mask&has_pcr_cross210]['weight'])
    
    for i, b in enumerate(bin_values):
        #Running 2PCF
        c210_2pcf, mean_bin_c210, edges, c210_err = clustering.correlation_function(x1, y1, x2, y2, \
                                                                                    bins = b, \
                                                                                    ranges = ranges, \
                                                                                    get_error=True, \
                                                                                    nrands = nrands, \
                                                                                    w1 = w1, w2 = w2)
        #Masking empty bins
        mask_empty_bins = (c210_2pcf**2>=0)&(c210_err**2>=0)
        plt.errorbar(mean_bin_c210[mask_empty_bins], c210_2pcf[mask_empty_bins], c210_err[mask_empty_bins], \
                     c = colors_bins[i], label = str(b) + " bins", lw = 3)
    
    plt.legend()
    plt.xlabel('r (Km)')
    plt.ylabel(r'$\xi(r)$')
    plt.title("2PCF year "+ str(y))
    plt.ylim(-1,3)
    plt.show()
# Out:
# /home/isglobal.lan/apujol/anaconda3/envs/gen/lib/python3.8/site-packages/spatial_tools-1.0-py3.8.egg/spatial_tools/clustering.py:183: RuntimeWarning: invalid value encountered in true_divide
# /home/isglobal.lan/apujol/anaconda3/envs/gen/lib/python3.8/site-packages/spatial_tools-1.0-py3.8.egg/spatial_tools/clustering.py:183: RuntimeWarning: invalid value encountered in true_divide
# /home/isglobal.lan/apujol/anaconda3/envs/gen/lib/python3.8/site-packages/spatial_tools-1.0-py3.8.egg/spatial_tools/clustering.py:183: RuntimeWarning: invalid value encountered in true_divide
# /home/isglobal.lan/apujol/anaconda3/envs/gen/lib/python3.8/site-packages/spatial_tools-1.0-py3.8.egg/spatial_tools/clustering.py:183: RuntimeWarning: invalid value encountered in true_divide
# /home/isglobal.lan/apujol/anaconda3/envs/gen/lib/python3.8/site-packages/spatial_tools-1.0-py3.8.egg/spatial_tools/clustering.py:183: RuntimeWarning: invalid value encountered in true_divide

# %% [markdown]
# ### Finally chosen 2PCF parameters

# %%
#Number of spatial bins
bins = 10
bins_small_scale = 6
#Spatial range of scale in Km
ranges = [.0,60.]
range_small_scale = [0, 15]
#Number of random realisations
nrands = 20

# %% [markdown]
# ### 2PCF measurements

# %%
def get_2pcf_cross(dataframe, pcrpos, mask, bins, ranges, nrands, colour, \
                   get_error = True, show = True, lw = 2):
    #Defining input data from cross-sectional 2PCFs
    x1 = np.array(dataframe[mask&pcrpos]['lng'])
    y1 = np.array(dataframe[mask&pcrpos]['lat'])
    x2 = np.array(dataframe[mask]['lng'])
    y2 = np.array(dataframe[mask]['lat'])
    w1 = np.array(dataframe[mask&pcrpos]['weight'])
    w2 = np.array(dataframe[mask]['weight'])
    
    #Run 2PCF for cross-sectional
    cross_2pcf, mean_bin_cross, edges, cross_err = clustering.correlation_function(x1, y1, x2, y2, \
                                                                                bins = bins, \
                                                                                ranges = ranges, \
                                                                                get_error=get_error, \
                                                                                nrands = nrands, \
                                                                                w1 = w1, w2 = w2)
    #Plotting results for non-empty data
    mask_empty_bins = (cross_2pcf**2>=0)&(cross_err**2>=0)
    if show:
        plt.errorbar(mean_bin_cross[mask_empty_bins], cross_2pcf[mask_empty_bins], \
                     cross_err[mask_empty_bins], c = 'k', label = "Children 2-10", \
                    linestyle = '--', lw = lw)
    return cross_2pcf, mean_bin_cross, edges, cross_err

def get_2pcf_mipmon(dataframe, pcrpos, mask, bins, ranges, nrands, colour, \
                    get_error = True, show = True, label = '', mode = 'auto', \
                    cross_df = None, cross_pcrpos = None, cross_mask = None, \
                   lw = 2):
    #Defining input data from ANC 2PCFs
    x1 = np.array(dataframe[mask&pcrpos]['longitude'])
    y1 = np.array(dataframe[mask&pcrpos]['latitude'])
    x2 = np.array(dataframe[mask]['longitude'])
    y2 = np.array(dataframe[mask]['latitude'])
    w1 = None
    w2 = None
    if mode == 'cross':
        x1x = np.array(cross_df[cross_mask&cross_pcrpos]['lng'])
        y1x = np.array(cross_df[cross_mask&cross_pcrpos]['lat'])
        x2x = np.array(cross_df[cross_mask]['lng'])
        y2x = np.array(cross_df[cross_mask]['lat'])
        w1x = np.array(cross_df[cross_mask&cross_pcrpos]['weight'])
        w2x = np.array(cross_df[cross_mask]['weight'])
    elif mode == 'auto':
        x1x, y1x, x2x, y2x, w1x, w2x = None, None, None, None, None, None
    else:
        print("WARNING: invalid value of mode", mode, ", assuming auto")
        x1x, y1x, x2x, y2x, w1x, w2x = None, None, None, None, None, None
    
    #Run 2PCF for ANC
    mip_2pcf, mean_bin_mip, edges, \
    mip_err = clustering.correlation_function(x1, y1, x2, y2, \
                                              bins = bins, ranges = ranges, \
                                              get_error=get_error, \
                                              nrands = nrands, \
                                              w1 = w1, w2 = w2, \
                                              x1x = x1x, y1x = y1x, \
                                              x2x = x2x, y2x = y2x, w1x = w1x, w2x = w2x)
    #Plotting results for non-empty data
    mask_empty_bins = (mip_2pcf**2>=0)&(mip_err**2>=0)
    if show:
        plt.errorbar(mean_bin_mip[mask_empty_bins], mip_2pcf[mask_empty_bins], \
                     mip_err[mask_empty_bins], c = colour, label = label, lw = lw)
    return mip_2pcf, mean_bin_mip, edges, mip_err

def get_2pcf_mipmon_selections(dataframe, pcrpos, mipmon_selection, mask, bins, ranges, nrands, \
                               colours, get_error = True, show = True, mode = 'auto', \
                               cross_df = None, cross_pcrpos = None, cross_mask = None, \
                              lw = 2):
    mip_2pcf, mean_bin_mip, edges, mip_err = {}, {}, {}, {}
    for c, s in enumerate(mipmon_selection):
        #Run 2PCF for ANC
        mip_2pcf[s], mean_bin_mip[s], edges[s], \
        mip_err[s] = get_2pcf_mipmon(dataframe, pcrpos, mask&mipmon_selection[s], \
                                             bins, ranges, get_error=get_error, nrands = nrands, \
                                             colour = colours[c], label = s, mode = mode, \
                                    cross_df = cross_df, cross_pcrpos = cross_pcrpos, \
                                     cross_mask = cross_mask, lw = lw)
    return mip_2pcf, mean_bin_mip, edges, mip_err

def get_all_2pcf_years(mipmon_df, mip_pcrpos, mipmon_selection, mip_mask, cross_df, cross_pcrpos, cross_mask, bins, \
                       ranges, nrands, colors_mipmon, colour_cross, get_error = True, show = True, verbose = False, \
                       time_width = None, mode = 'auto', ylims = [-1,3], ncol = 1, lw = 2, fontsize = None):
    #Dictionary to store results from ANC data
    mip_2pcf, mean_bin_mip, edges, mip_err = {}, {}, {}, {}
    cross_2pcf, mean_bin_cross, edges, cross_err  = {}, {}, {}, {}
    
    for y in years:
        #Mask to select the year of the data
        #cross_mask_time = cross_df['year'] == y
        #mip_mask_time = mipmon_df['year'] == y
        cross_mask_time, mip_mask_time = get_time_masks(cross_df, mipmon_df, y, time_width = time_width)
        
        #Run 2PCF for all ANC selections
        if verbose:
            print('Sample size all 1st ANC:', np.sum(mip_mask_time&mip_mask))
        mip_2pcf[str(y)], mean_bin_mip[str(y)], edges[str(y)], mip_err[str(y)] = \
        get_2pcf_mipmon_selections(mipmon_df, mip_pcrpos, mipmon_selection, \
                                   mip_mask_time&mip_mask, bins, ranges, nrands, \
                                   colors_mipmon, get_error = get_error, show = show, \
                                   mode = mode, cross_df = cross_df, \
                                   cross_pcrpos = cross_pcrpos, \
                                   cross_mask = cross_mask_time&cross_mask, lw = lw)
        
        
        
        #Run 2PCF for cross-sectional
        if verbose:
            print('Sample size cross-sectional:', np.sum(cross_mask_time&cross_mask))
        cross_2pcf[str(y)], mean_bin_cross[str(y)], edges[str(y)], cross_err[str(y)] = \
        get_2pcf_cross(cross_df, cross_pcrpos, cross_mask_time&cross_mask, bins, \
                       ranges, nrands, colour_cross, get_error = get_error, show = show, \
                      lw = lw)
        
        
        plt.hlines(0, ranges[0] - 2, ranges[1] + 2, color = 'tab:grey')
        plt.xlim(ranges[0] - 2, ranges[1] + 2)
        #plt.legend(ncol = ncol, fontsize = fontsize, framealpha = 1)
        plt.xlabel('r (Km)', fontsize = fontsize)
        plt.ylabel(r'$\xi(r)$ year '+ str(y), fontsize = fontsize)
        #plt.title("2PCF year "+ str(y))
        plt.yticks(fontsize = fontsize)
        plt.xticks(fontsize = fontsize)
        plt.ylim(ylims)
        plt.show()
    return mip_2pcf, mean_bin_mip, edges, mip_err, cross_2pcf, mean_bin_cross, edges, cross_err

def get_time_masks(cross_df, mipmon_df, year, time_width = None, verbose = False):
    #Mask to select the year of the data
    cross_mask = cross_df['year'] == year
    if verbose:
        print('Sample size cross-sectional:', np.sum(cross_mask))
    if time_width is None:
        mip_mask = mipmon_df['year'] == year
    else:
        mean_cross_data = cross_df['visdate'][cross_mask].mean()
        mip_mask = get_time_mask_mipmon(mipmon_df, mean_cross_data, time_width, verbose = verbose)
    return cross_mask, mip_mask

def get_time_mask_mipmon(mipmon_df, date, time_width, verbose = True):
    #Selection a window aroung the cross-sectional data for ANC
    time_0 = date - pd.to_timedelta(time_width/2, unit = 'D')
    time_1 = date + pd.to_timedelta(time_width/2, unit = 'D')
    mip_mask = (mipmon_df['visdate'] >= time_0)&(mipmon_df['visdate'] <= time_1)
    if verbose:
        print('Sample size all 1st ANC:', np.sum(mip_mask))
    return mip_mask

# %%
for y in years[:2]:
    #Mask to select the year of the data
    #cross_mask_time = cross_df['year'] == y
    #mip_mask_time = mipmon_df['year'] == y
    cross_mask_time, mip_mask_time = get_time_masks(cross210, mipmon, y, time_width = None) 
    #Run 2PCF for cross-sectional
    mask = cross_mask_time&has_pcr_cross210&cross210_area_mask
    #Defining input data from cross-sectional 2PCFs
    x1 = np.array(cross210[mask&cross210_pcrpos]['lng'])
    y1 = np.array(cross210[mask&cross210_pcrpos]['lat'])
    x2 = np.array(cross210[mask]['lng'])
    y2 = np.array(cross210[mask]['lat'])
    w1 = np.array(cross210[mask&cross210_pcrpos]['weight'])
    w2 = np.array(cross210[mask]['weight'])
    
    #Run 2PCF for cross-sectional
    cross_2pcf, mean_bin_cross, edges, cross_err = clustering.correlation_function(x1, y1, x2, y2, \
                                                                                bins = bins, \
                                                                                ranges = range_small_scale, \
                                                                                get_error=True, \
                                                                                nrands = nrands, \
                                                                                w1 = w1, w2 = w2)
    
    numpairs_p, errors_p, weighted_bins_p, edges_p, mean_bootstrap_p = clustering.num_pairs_bootstrap(x1, y1, x1, y1, \
                                                                                                      bins, range_small_scale, \
                                                                                 nrands = 10, mode = 'latlon', \
                                                                                 w1 = w1)
    numpairs_t, errors_t, weighted_bins_t, edges_t, mean_bootstrap_t = clustering.num_pairs_bootstrap(x2, y2, x2, y2, \
                                                                                                      bins, range_small_scale, \
                                                                                 nrands = 10, mode = 'latlon', \
                                                                                 w1 = w2)
    #Plotting results for non-empty data
    mask_empty_bins = (cross_2pcf**2>=0)&(cross_err**2>=0)
    plt.errorbar(mean_bin_cross[mask_empty_bins], cross_2pcf[mask_empty_bins], \
                     cross_err[mask_empty_bins], c = 'k', label = "Children 2-10", \
                    linestyle = '--')
    plt.show()
    plt.errorbar(weighted_bins_p[mask_empty_bins], numpairs_p[mask_empty_bins]/len(x1)**2, \
                     errors_p[mask_empty_bins]/len(x1)**2, c = 'tab:green', label = "positive", \
                    linestyle = '--')
    plt.errorbar(weighted_bins_t[mask_empty_bins], numpairs_t[mask_empty_bins]/len(x2)**2, \
                     errors_t[mask_empty_bins]/len(x2)**2, c = 'tab:orange', label = "negative", \
                    linestyle = '--')
    plt.legend()
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_29005/2558353533.py in <module>
#      15
#      16     #Run 2PCF for cross-sectional
# ---> 17     cross_2pcf, mean_bin_cross, edges, cross_err = clustering.correlation_function(x1, y1, x2, y2, \
#      18                                                                                 bins = bins, \
#      19                                                                                 ranges = range_small_scale, \
#
# ~/anaconda3/envs/gen/lib/python3.8/site-packages/spatial_tools-1.0-py3.8.egg/spatial_tools/clustering.py in correlation_function(x1, y1, x2, y2, bins, ranges, mode, get_error, nrands, w1, w2, x1x, y1x, w1x, x2x, y2x, w2x)
#     354                                                 w1 = w1, w2 = w1x)
#     355         numpairs_2, errors_2, weighted_bins_2, edges_2, mean_bootstrap_2, \
# ...

# %% [markdown]
# 2PCF statistics will be obtained for the three cross-sectional data separately, and the same measurements will be done for the different populations of pregnant women (all first ANC visits, primigravid women, multigravid women, HIV+ women and HIV- women). Data from pregnant women will be selected around the dates of the cross-sectional surveys. The temporal window for the selection of pregnant women will be chosen with two purposes:
#
# a) To compare the results with similar sample sizes, selecting the temporal windows to obtain a similar sample size than the data from children
#
# b) To assess the impact of using a larger time window in pregnant women to increase the precision of the measurements with respect to cross-sectional surveys

# %% [markdown]
# ### Using the whole year ANC data

# %%
mipmon_selection = {
    'All ANC visits' : mipmon_pn,
    'Primigravidae' : mipmon_pg,
    #'Secundigravid' : mipmon_sg,
    #'1-2gravid' : mipmon_12g,
    #'>2gravid' : mipmon_3g,
    'Multigravidae' : mipmon_mg,
    'HIV+' : mipmon_hiv_pos,
    'HIV-' : mipmon_hiv_neg,
    #'PG HIV+' : mipmon_pg_hiv_pos,
    'Primigravid HIV-' : mipmon_pg_hiv_neg,
}

# %%
#Using RDT results, cross-correlation
mip_2pcf_y_rdt_x, mean_bin_mip_y_rdt_x, edges_y_rdt_x, mip_err_y_rdt_x, cross_2pcf_rdt_x, mean_bin_cross_rdt_x, edges_x, cross_err_rdt_x = \
get_all_2pcf_years(mipmon, mip_rdtpos, mipmon_selection, prenatal, cross210, cross210_rdtpos, \
                   has_pcr_cross210&cross210_area_mask, bins, ranges, nrands, colors_mipmon, 'k', \
                   mode = 'cross', lw = 2, fontsize = 18)
# Out:
# /home/isglobal.lan/apujol/anaconda3/envs/gen/lib/python3.8/site-packages/spatial_tools-1.0-py3.8.egg/spatial_tools/clustering.py:183: RuntimeWarning: invalid value encountered in true_divide
# /home/isglobal.lan/apujol/anaconda3/envs/gen/lib/python3.8/site-packages/spatial_tools-1.0-py3.8.egg/spatial_tools/clustering.py:183: RuntimeWarning: invalid value encountered in true_divide
# /home/isglobal.lan/apujol/anaconda3/envs/gen/lib/python3.8/site-packages/spatial_tools-1.0-py3.8.egg/spatial_tools/clustering.py:183: RuntimeWarning: invalid value encountered in true_divide
# /home/isglobal.lan/apujol/anaconda3/envs/gen/lib/python3.8/site-packages/spatial_tools-1.0-py3.8.egg/spatial_tools/clustering.py:183: RuntimeWarning: invalid value encountered in true_divide
# /home/isglobal.lan/apujol/anaconda3/envs/gen/lib/python3.8/site-packages/spatial_tools-1.0-py3.8.egg/spatial_tools/clustering.py:183: RuntimeWarning: invalid value encountered in true_divide
# ...

# %%
#Using PCR results, cross-correlation
mip_2pcf_y_x, mean_bin_mip_y_x, edges_y_x, mip_err_y_x, cross_2pcf_x, mean_bin_cross_x, edges_x, cross_err_x = \
get_all_2pcf_years(mipmon, mip_pcrpos, mipmon_selection, prenatal, cross210, cross210_pcrpos, \
                   has_pcr_cross210&cross210_area_mask, bins, ranges, nrands, colors_mipmon, 'k', \
                   mode = 'cross', lw = 2, fontsize = 18)
# Out:
# /home/isglobal.lan/apujol/anaconda3/envs/gen/lib/python3.8/site-packages/spatial_tools-1.0-py3.8.egg/spatial_tools/clustering.py:183: RuntimeWarning: invalid value encountered in true_divide
# /home/isglobal.lan/apujol/anaconda3/envs/gen/lib/python3.8/site-packages/spatial_tools-1.0-py3.8.egg/spatial_tools/clustering.py:183: RuntimeWarning: invalid value encountered in true_divide
# /home/isglobal.lan/apujol/anaconda3/envs/gen/lib/python3.8/site-packages/spatial_tools-1.0-py3.8.egg/spatial_tools/clustering.py:183: RuntimeWarning: invalid value encountered in true_divide
# /home/isglobal.lan/apujol/anaconda3/envs/gen/lib/python3.8/site-packages/spatial_tools-1.0-py3.8.egg/spatial_tools/clustering.py:183: RuntimeWarning: invalid value encountered in true_divide
# /home/isglobal.lan/apujol/anaconda3/envs/gen/lib/python3.8/site-packages/spatial_tools-1.0-py3.8.egg/spatial_tools/clustering.py:183: RuntimeWarning: invalid value encountered in true_divide
# ...

# %%
#Using PCR results, cross-correlation
mip_2pcf_y_x, mean_bin_mip_y_x, edges_y_x, mip_err_y_x, cross_2pcf_x, mean_bin_cross_x, edges_x, cross_err_x = \
get_all_2pcf_years(mipmon, mip_pcrpos, mipmon_selection, prenatal, cross210, cross210_pcrpos, \
                   has_pcr_cross210&cross210_area_mask, bins, ranges, nrands, colors_mipmon, 'k', \
                   mode = 'cross', lw = 2)
# Out:
# /home/isglobal.lan/apujol/anaconda3/envs/gen/lib/python3.8/site-packages/spatial_tools-1.0-py3.8.egg/spatial_tools/clustering.py:183: RuntimeWarning: invalid value encountered in true_divide
# /home/isglobal.lan/apujol/anaconda3/envs/gen/lib/python3.8/site-packages/spatial_tools-1.0-py3.8.egg/spatial_tools/clustering.py:183: RuntimeWarning: invalid value encountered in true_divide
# /home/isglobal.lan/apujol/anaconda3/envs/gen/lib/python3.8/site-packages/spatial_tools-1.0-py3.8.egg/spatial_tools/clustering.py:183: RuntimeWarning: invalid value encountered in true_divide
# /home/isglobal.lan/apujol/anaconda3/envs/gen/lib/python3.8/site-packages/spatial_tools-1.0-py3.8.egg/spatial_tools/clustering.py:183: RuntimeWarning: invalid value encountered in true_divide
# /home/isglobal.lan/apujol/anaconda3/envs/gen/lib/python3.8/site-packages/spatial_tools-1.0-py3.8.egg/spatial_tools/clustering.py:183: RuntimeWarning: invalid value encountered in true_divide
# ...

# %%
#Using PCR results
mip_2pcf_y, mean_bin_mip_y, edges_y, mip_err_y, cross_2pcf, mean_bin_cross, edges, cross_err = \
get_all_2pcf_years(mipmon, mip_pcrpos, mipmon_selection, prenatal, cross210, cross210_pcrpos, \
                   has_pcr_cross210&cross210_area_mask, bins, ranges, nrands, colors_mipmon, 'k', \
                   mode = 'auto', lw = 2)
# Out:
# /home/isglobal.lan/apujol/anaconda3/envs/gen/lib/python3.8/site-packages/spatial_tools-1.0-py3.8.egg/spatial_tools/clustering.py:183: RuntimeWarning: invalid value encountered in true_divide
# /home/isglobal.lan/apujol/anaconda3/envs/gen/lib/python3.8/site-packages/spatial_tools-1.0-py3.8.egg/spatial_tools/clustering.py:183: RuntimeWarning: invalid value encountered in true_divide
# /home/isglobal.lan/apujol/anaconda3/envs/gen/lib/python3.8/site-packages/spatial_tools-1.0-py3.8.egg/spatial_tools/clustering.py:183: RuntimeWarning: invalid value encountered in true_divide
# /home/isglobal.lan/apujol/anaconda3/envs/gen/lib/python3.8/site-packages/spatial_tools-1.0-py3.8.egg/spatial_tools/clustering.py:183: RuntimeWarning: invalid value encountered in true_divide
# /home/isglobal.lan/apujol/anaconda3/envs/gen/lib/python3.8/site-packages/spatial_tools-1.0-py3.8.egg/spatial_tools/clustering.py:183: RuntimeWarning: invalid value encountered in true_divide
# ...

# %%
#Correlating parity
selections = ['All ANC visits', 'Primigravidae', 'Multigravidae']
lw = 2

for year in years:
    for i, sel in enumerate(selections):
        mask = (mipmon['year'] == year)&(mipmon['pcrpos'].notnull())
        selection1 = mipmon_selection['All ANC visits']
        selection2 = mipmon_selection[sel]
        
        x1 = np.array(mipmon[mask&selection1&(mipmon['pcrpos'] == 1)]['longitude'])
        y1 = np.array(mipmon[mask&selection1&(mipmon['pcrpos'] == 1)]['latitude'])
        x2 = np.array(mipmon[mask&selection1]['longitude'])
        y2 = np.array(mipmon[mask&selection1]['latitude'])
        x1x = np.array(mipmon[mask&selection2&(mipmon['pcrpos'] == 1)]['longitude'])
        y1x = np.array(mipmon[mask&selection2&(mipmon['pcrpos'] == 1)]['latitude'])
        x2x = np.array(mipmon[mask&selection2]['longitude'])
        y2x = np.array(mipmon[mask&selection2]['latitude'])
        
        
        mip_2pcf, mean_bin_mip, edges, mip_err = clustering.correlation_function(x1, y1, x2, y2, \
                                                      bins = bins, ranges = ranges, \
                                                      get_error=True, \
                                                      nrands = nrands, \
                                                      w1 = None, w2 = None, \
                                                      x1x = x1x, y1x = y1x, \
                                                      x2x = x2x, y2x = y2x, w1x = None, w2x = None)
        #Plotting results for non-empty data
        mask_empty_bins = (mip_2pcf**2>=0)&(mip_err**2>=0)
        plt.errorbar(mean_bin_mip[mask_empty_bins], mip_2pcf[mask_empty_bins], \
                    mip_err[mask_empty_bins], c = colors_mipmon[i], label = sel, lw = lw)
    plt.title("Cross 2PCF with All ANC visits, year " + str(year))
    plt.show()
# Out:
# /home/isglobal.lan/apujol/anaconda3/envs/gen/lib/python3.8/site-packages/spatial_tools-1.0-py3.8.egg/spatial_tools/clustering.py:183: RuntimeWarning: invalid value encountered in true_divide
#   weighted_bins /= numpairs
# /home/isglobal.lan/apujol/anaconda3/envs/gen/lib/python3.8/site-packages/spatial_tools-1.0-py3.8.egg/spatial_tools/clustering.py:183: RuntimeWarning: invalid value encountered in true_divide
#   weighted_bins /= numpairs

# %%
#Checking small scales only
mip_2pcf_y_ss, mean_bin_mip_y_ss, edges_y_ss, mip_err_y_ss, cross_2pcf_ss, mean_bin_cross_ss, edges_ss, cross_err_ss = \
get_all_2pcf_years(mipmon, mip_pcrpos, mipmon_selection, prenatal, cross210, cross210_pcrpos, \
                   has_pcr_cross210&cross210_area_mask, bins_small_scale, range_small_scale, \
                   nrands, colors_mipmon, 'k')
# Out:
# /home/isglobal.lan/apujol/anaconda3/envs/gen/lib/python3.8/site-packages/spatial_tools-1.0-py3.8.egg/spatial_tools/clustering.py:183: RuntimeWarning: invalid value encountered in true_divide
# /home/isglobal.lan/apujol/anaconda3/envs/gen/lib/python3.8/site-packages/spatial_tools-1.0-py3.8.egg/spatial_tools/clustering.py:183: RuntimeWarning: invalid value encountered in true_divide
# /home/isglobal.lan/apujol/anaconda3/envs/gen/lib/python3.8/site-packages/spatial_tools-1.0-py3.8.egg/spatial_tools/clustering.py:183: RuntimeWarning: invalid value encountered in true_divide
# /home/isglobal.lan/apujol/anaconda3/envs/gen/lib/python3.8/site-packages/spatial_tools-1.0-py3.8.egg/spatial_tools/clustering.py:183: RuntimeWarning: invalid value encountered in true_divide
# /home/isglobal.lan/apujol/anaconda3/envs/gen/lib/python3.8/site-packages/spatial_tools-1.0-py3.8.egg/spatial_tools/clustering.py:183: RuntimeWarning: invalid value encountered in true_divide

# %%
#Applying a mask to Cross-sectionals to only include the three catchment areas from MiPMon
mip_2pcf_y, mean_bin_mip_y, edges_y, mip_err_y, cross_2pcf, mean_bin_cross, edges, cross_err = \
get_all_2pcf_years(mipmon, mip_pcrpos, mipmon_selection, prenatal, cross210, cross210_pcrpos, \
                   has_pcr_cross210&cross210_area_mask, bins, ranges, nrands, colors_mipmon, 'k', \
                   mode = 'cross')
# Out:
# /home/isglobal.lan/apujol/anaconda3/envs/gen/lib/python3.8/site-packages/spatial_tools-1.0-py3.8.egg/spatial_tools/clustering.py:183: RuntimeWarning: invalid value encountered in true_divide
# /home/isglobal.lan/apujol/anaconda3/envs/gen/lib/python3.8/site-packages/spatial_tools-1.0-py3.8.egg/spatial_tools/clustering.py:183: RuntimeWarning: invalid value encountered in true_divide
# /home/isglobal.lan/apujol/anaconda3/envs/gen/lib/python3.8/site-packages/spatial_tools-1.0-py3.8.egg/spatial_tools/clustering.py:183: RuntimeWarning: invalid value encountered in true_divide
# /home/isglobal.lan/apujol/anaconda3/envs/gen/lib/python3.8/site-packages/spatial_tools-1.0-py3.8.egg/spatial_tools/clustering.py:183: RuntimeWarning: invalid value encountered in true_divide
# /home/isglobal.lan/apujol/anaconda3/envs/gen/lib/python3.8/site-packages/spatial_tools-1.0-py3.8.egg/spatial_tools/clustering.py:183: RuntimeWarning: invalid value encountered in true_divide
# ...

# %%
#Applying a mask to Cross-sectionals to only include the three catchment areas from MiPMon, small scales
mip_2pcf_y, mean_bin_mip_y, edges_y, mip_err_y, cross_2pcf, mean_bin_cross, edges, cross_err = \
get_all_2pcf_years(mipmon, mip_pcrpos, mipmon_selection, prenatal, cross210, cross210_pcrpos, \
                   has_pcr_cross210&cross210_area_mask, bins_small_scale, range_small_scale, \
                   nrands, colors_mipmon, 'k', mode = 'cross')
# Out:
# /home/isglobal.lan/apujol/anaconda3/envs/gen/lib/python3.8/site-packages/spatial_tools-1.0-py3.8.egg/spatial_tools/clustering.py:183: RuntimeWarning: invalid value encountered in true_divide
# /home/isglobal.lan/apujol/anaconda3/envs/gen/lib/python3.8/site-packages/spatial_tools-1.0-py3.8.egg/spatial_tools/clustering.py:183: RuntimeWarning: invalid value encountered in true_divide
# /home/isglobal.lan/apujol/anaconda3/envs/gen/lib/python3.8/site-packages/spatial_tools-1.0-py3.8.egg/spatial_tools/clustering.py:183: RuntimeWarning: invalid value encountered in true_divide
# /home/isglobal.lan/apujol/anaconda3/envs/gen/lib/python3.8/site-packages/spatial_tools-1.0-py3.8.egg/spatial_tools/clustering.py:183: RuntimeWarning: invalid value encountered in true_divide

# %% [markdown]
# ### Testing very small scales

# %%
#Checking small scales only
mip_2pcf_y_ss, mean_bin_mip_y_ss, edges_y_ss, mip_err_y_ss, cross_2pcf_ss, mean_bin_cross_ss, edges_ss, cross_err_ss = \
get_all_2pcf_years(mipmon, mip_pcrpos, mipmon_selection, prenatal, cross210, cross210_pcrpos, \
                   has_pcr_cross210&cross210_area_mask, bins_small_scale, [0,3], \
                   nrands, colors_mipmon, 'k')
# Out:
# /home/isglobal.lan/apujol/anaconda3/envs/gen/lib/python3.8/site-packages/spatial_tools-1.0-py3.8.egg/spatial_tools/clustering.py:183: RuntimeWarning: invalid value encountered in true_divide
# /home/isglobal.lan/apujol/anaconda3/envs/gen/lib/python3.8/site-packages/spatial_tools-1.0-py3.8.egg/spatial_tools/clustering.py:183: RuntimeWarning: invalid value encountered in true_divide
# /home/isglobal.lan/apujol/anaconda3/envs/gen/lib/python3.8/site-packages/spatial_tools-1.0-py3.8.egg/spatial_tools/clustering.py:183: RuntimeWarning: invalid value encountered in true_divide
# /home/isglobal.lan/apujol/anaconda3/envs/gen/lib/python3.8/site-packages/spatial_tools-1.0-py3.8.egg/spatial_tools/clustering.py:183: RuntimeWarning: invalid value encountered in true_divide
# /home/isglobal.lan/apujol/anaconda3/envs/gen/lib/python3.8/site-packages/spatial_tools-1.0-py3.8.egg/spatial_tools/clustering.py:183: RuntimeWarning: invalid value encountered in true_divide
# ...

# %% [markdown]
# #### Using smaller time windows for the ANC selection

# %%
#Define time width
time_width = 90
print("For time window of", str(time_width), "days:")
#Dictionary to store results from ANC data
mip_2pcf, mean_bin_mip, edges, mip_err = {}, {}, {}, {}
c210_2pcf, mean_bin_c210, edges, c210_err  = {}, {}, {}, {}

for y in years:
    #Mask to select the year of the data
    c210_mask = cross210['year'] == y
    print('Sample size children 2-10:', np.sum(c210_mask))
    mean_cross_data = cross210['visdate'][c210_mask].mean()
    #Selection a window aroung the cross-sectional data for ANC
    time_0 = mean_cross_data - pd.to_timedelta(time_width/2, unit = 'D')
    time_1 = mean_cross_data + pd.to_timedelta(time_width/2, unit = 'D')
    mip_mask = (mipmon['visdate'] >= time_0)&(mipmon['visdate'] <= time_1)&mipmon_pn
    print('Sample size all 1st ANC:', np.sum(mip_mask))
# Out:
# For time window of 90 days:
# Sample size children 2-10: 3087
# Sample size all 1st ANC: 490
# Sample size children 2-10: 3116
# Sample size all 1st ANC: 391
# Sample size children 2-10: 846
# Sample size all 1st ANC: 388

# %%
#Define time width
time_width = 90
print("For time window of", str(time_width), "days:")
mip_2pcf_tw90, mean_bin_mip_tw90, edges_tw90, mip_err_tw90, cross_2pcf, mean_bin_cross, edges, cross_err = \
get_all_2pcf_years(mipmon, mip_pcrpos, mipmon_selection, prenatal, cross210, cross210_pcrpos, \
                   has_pcr_cross210, bins, ranges, nrands, colors_mipmon, 'k', \
                   time_width = time_width, verbose = True)
# Out:
# For time window of 90 days:
# Sample size cross-sectional: 3087
# Sample size all 1st ANC: 1422
# /home/isglobal.lan/apujol/anaconda3/envs/gen/lib/python3.8/site-packages/spatial_tools-1.0-py3.8.egg/spatial_tools/clustering.py:183: RuntimeWarning: invalid value encountered in true_divide
#   weighted_bins /= numpairs
# /home/isglobal.lan/apujol/anaconda3/envs/gen/lib/python3.8/site-packages/spatial_tools-1.0-py3.8.egg/spatial_tools/clustering.py:183: RuntimeWarning: invalid value encountered in true_divide
#   weighted_bins /= numpairs
# Sample size cross-sectional: 3116
# Sample size all 1st ANC: 1516
# /home/isglobal.lan/apujol/anaconda3/envs/gen/lib/python3.8/site-packages/spatial_tools-1.0-py3.8.egg/spatial_tools/clustering.py:183: RuntimeWarning: invalid value encountered in true_divide
#   weighted_bins /= numpairs
# ...

# %%
#Define time width
time_width = 180
print("For time window of", str(time_width), "days:")
mip_2pcf_tw180, mean_bin_mip_tw180, edges_tw180, mip_err_tw180, cross_2pcf, mean_bin_cross, edges, cross_err = \
get_all_2pcf_years(mipmon, mip_pcrpos, mipmon_selection, prenatal, cross210, cross210_pcrpos, \
                   has_pcr_cross210, bins, ranges, nrands, colors_mipmon, 'k', time_width = time_width)
# Out:
# For time window of 180 days:
# /home/isglobal.lan/apujol/anaconda3/envs/gen/lib/python3.8/site-packages/spatial_tools-1.0-py3.8.egg/spatial_tools/clustering.py:183: RuntimeWarning: invalid value encountered in true_divide
#   weighted_bins /= numpairs
# /home/isglobal.lan/apujol/anaconda3/envs/gen/lib/python3.8/site-packages/spatial_tools-1.0-py3.8.egg/spatial_tools/clustering.py:183: RuntimeWarning: invalid value encountered in true_divide
#   weighted_bins /= numpairs
# /home/isglobal.lan/apujol/anaconda3/envs/gen/lib/python3.8/site-packages/spatial_tools-1.0-py3.8.egg/spatial_tools/clustering.py:183: RuntimeWarning: invalid value encountered in true_divide
#   weighted_bins /= numpairs
# /home/isglobal.lan/apujol/anaconda3/envs/gen/lib/python3.8/site-packages/spatial_tools-1.0-py3.8.egg/spatial_tools/clustering.py:183: RuntimeWarning: invalid value encountered in true_divide
#   weighted_bins /= numpairs
# ...

# %% [markdown]
# ## Impact of time width on pregnant women 2PCF

# %%
for y in years:
    for c, s in enumerate(mipmon_selection):
        plt.errorbar(mean_bin_mip_y[str(y)][s], mip_2pcf_y[str(y)][s], mip_err_y[str(y)][s], label = 'tw=1y')
        plt.errorbar(mean_bin_mip_tw90[str(y)][s], mip_2pcf_tw90[str(y)][s], mip_err_tw90[str(y)][s], label = 'tw=90')
        plt.errorbar(mean_bin_mip_tw180[str(y)][s], mip_2pcf_tw180[str(y)][s], mip_err_tw180[str(y)][s], label = 'tw=180')
        plt.legend()
        plt.xlabel('r (Km)')
        plt.ylabel(r'$\xi(r)$')
        plt.title("2PCF year " + str(y) +" " + s)
        plt.ylim(-1,3)
        plt.show()

# %% [markdown]
# ### Consistency analysis:
#
# $\chi²$ Statistics will be obtained comparing the 2PCF measurement in children with the different populations of pregnant women. Values larger than a chi2 threshold will be considered as different results between the two populations. Alternatively, t-test statistics will be used for the same purpose (they should give the same conclusions).

# %%
chi2_y_x = {}
for y in years:
    chi2_y_x[str(y)] = {}
    for s in mipmon_selection:
        mask = (cross_err_x[str(y)]**2 > 0)&(mip_err_y_x[str(y)][s]**2 > 0)
        chi2_y_x[str(y)][s] = errors.chi_square(cross_2pcf_x[str(y)][mask], cross_err_x[str(y)][mask], \
                                                mip_2pcf_y_x[str(y)][s][mask], mip_err_y_x[str(y)][s][mask])
chi2_y_x = pd.DataFrame(chi2_y_x)

# %%
chi2_y_x
# Out:
#                          1         2         3
# All ANC visits    0.365875  0.917007  0.537146
# Primigravidae     0.679129  0.855365  0.586107
# Multigravidae     0.469690  1.062683  0.520607
# HIV+              0.630784  1.009333  0.648411
# HIV-              0.398296  1.044245  0.642962
# Primigravid HIV-  0.419376  1.187874  0.490723

# %%
chi2_y_rdt_x = {}
for y in years:
    chi2_y_rdt_x[str(y)] = {}
    for s in mipmon_selection:
        mask = (cross_err_rdt_x[str(y)]**2 > 0)&(mip_err_y_rdt_x[str(y)][s]**2 > 0)
        chi2_y_rdt_x[str(y)][s] = errors.chi_square(cross_2pcf_rdt_x[str(y)][mask], cross_err_rdt_x[str(y)][mask], \
                                                    mip_2pcf_y_rdt_x[str(y)][s][mask], mip_err_y_rdt_x[str(y)][s][mask])
chi2_y_rdt_x = pd.DataFrame(chi2_y_rdt_x)

# %%
chi2_y_rdt_x
# Out:
#                          1         2         3
# All ANC visits    0.538899  0.912150  0.835457
# Primigravidae     0.460501  0.815435  0.791926
# Multigravidae     0.624530  0.521962  0.482090
# HIV+              0.472295  0.509448  0.406621
# HIV-              0.445155  0.781757  0.377320
# Primigravid HIV-  0.413872  0.921920  0.515534

# %%
chi2_y = {}
for y in years:
    chi2_y[str(y)] = {}
    for s in mipmon_selection:
        mask = (cross_err[str(y)]**2 > 0)&(mip_err_y[str(y)][s]**2 > 0)
        chi2_y[str(y)][s] = errors.chi_square(cross_2pcf[str(y)][mask], cross_err[str(y)][mask], mip_2pcf_y[str(y)][s][mask], mip_err_y[str(y)][s][mask])
chi2_y = pd.DataFrame(chi2_y)

# %%
chi2_y = {}
for y in years:
    chi2_y[str(y)] = {}
    for s in mipmon_selection:
        mask = (cross_err[str(y)]**2 > 0)&(mip_err_y[str(y)][s]**2 > 0)
        chi2_y[str(y)][s] = errors.chi_square(cross_2pcf[str(y)][mask], cross_err[str(y)][mask], mip_2pcf_y[str(y)][s][mask], mip_err_y[str(y)][s][mask])
chi2_y = pd.DataFrame(chi2_y)

chi2_tw90 = {}
for y in years:
    chi2_tw90[str(y)] = {}
    for s in mipmon_selection:
        mask = (cross_err[str(y)]**2 > 0)&(mip_err_tw90[str(y)][s]**2 > 0)
        chi2_tw90[str(y)][s] = errors.chi_square(cross_2pcf[str(y)][mask], cross_err[str(y)][mask], mip_2pcf_tw90[str(y)][s][mask], mip_err_tw90[str(y)][s][mask])
chi2_tw90 = pd.DataFrame(chi2_tw90)

chi2_tw180 = {}
for y in years:
    chi2_tw180[str(y)] = {}
    for s in mipmon_selection:
        mask = (cross_err[str(y)]**2 > 0)&(mip_err_tw180[str(y)][s]**2 > 0)
        chi2_tw180[str(y)][s] = errors.chi_square(cross_2pcf[str(y)][mask], cross_err[str(y)][mask], mip_2pcf_tw180[str(y)][s][mask], mip_err_tw180[str(y)][s][mask])
chi2_tw180 = pd.DataFrame(chi2_tw180)

# %%
chi2_y
# Out:
#                      1         2         3
# All prenatal  1.020183  3.075811  0.344290
# Primigravid   0.692032  1.761725  0.479808
# Multigravid   1.006575  3.699878  0.390625

# %%
chi2_y_x
# Out:
#                        1         2         3
# All ANC visits  0.454939  1.016504  0.765358
# Primigravidae   0.478069  0.535123  0.708979
# Multigravidae   0.386494  1.565450  0.578578

# %%
chi2_y_rdt
# Out:
#                      1         2         3
# All prenatal  0.690413  1.885573  0.434673
# Primigravid   0.939947  1.588841  0.128488
# Multigravid   0.567308  1.193428  0.607429

# %%
chi2_tw90
# Out:
#                   2017      2018      2019
# All prenatal  0.661283  0.867379  0.940249
# Primigravid   0.148306  0.721922  0.476990
# Multigravid   0.753049  0.645544  0.729169
# HIV+          0.904290  0.711458  0.581160
# HIV-          0.602468  0.832008  1.353742

# %%
chi2_tw180
# Out:
#                   2017      2018      2019
# All prenatal  1.128310  1.497844  0.721574
# Primigravid   0.549414  0.888550  0.770074
# Multigravid   1.292140  1.549350  0.847450
# HIV+          1.452483  1.002002  0.471223
# HIV-          0.874775  0.886421  0.591213

# %% [markdown]
# ###  Significance analysis:
#
# A t-test will be used to measure the statistical significance of the clustering signal of the different populations by measuring the deviation of the 2PCFs from zero. A table will be created describing the p-values of each population and year to identify the most significant clustering structures found.

# %%
from stat_tools import stats
import scipy.stats as sci_stats

# %%
def chi22p(chi2, dof):
    """This method translates from chi square statistics
    to p-value to get statistical significancy.
    
    Parameters:
    -----------
    chi2: float
        Value of chi square
    dof: int
        Number of degrees of freedom
    
    Returns:
    --------
    p: float
        P-value of statistical significance of the difference
    """
    p = 1 - sci_stats.chi2.cdf(chi2, dof)
    return p

# %%
sig_y_x = {}
p_y_x = {}
for y in years:
    sig_y_x[str(y)] = {}
    p_y_x[str(y)] = {}
    for s in mipmon_selection:
        mask = mip_err_y_x[str(y)][s]**2 > 0
        sig_y_x[str(y)][s] = errors.chi_square(mip_2pcf_y_x[str(y)][s][mask], mip_err_y_x[str(y)][s][mask], \
                                             0*mip_2pcf_y_x[str(y)][s][mask], 0*mip_err_y_x[str(y)][s][mask])
        p_y_x[str(y)][s] = chi22p(sig_y_x[str(y)][s]*bins, bins)
sig_y_x = pd.DataFrame(sig_y_x)
p_y_x = pd.DataFrame(p_y_x)



sig_y_rdt_x = {}
p_y_rdt_x = {}
for y in years:
    sig_y_rdt_x[str(y)] = {}
    p_y_rdt_x[str(y)] = {}
    for s in mipmon_selection:
        mask = mip_err_y_rdt_x[str(y)][s]**2 > 0
        sig_y_rdt_x[str(y)][s] = errors.chi_square(mip_2pcf_y_rdt_x[str(y)][s][mask], mip_err_y_rdt_x[str(y)][s][mask], \
                                             0*mip_2pcf_y_rdt_x[str(y)][s][mask], 0*mip_err_y_rdt_x[str(y)][s][mask])
        p_y_rdt_x[str(y)][s] = chi22p(sig_y_rdt_x[str(y)][s]*bins, bins)
sig_y_rdt_x = pd.DataFrame(sig_y_rdt_x)
p_y_rdt_x = pd.DataFrame(p_y_rdt_x)

# %%
p_y_x
# Out:
#                              1         2         3
# All ANC visits    0.000000e+00  0.000161  0.254307
# Primigravidae     5.161100e-07  0.008800  0.434050
# Multigravidae     1.155753e-11  0.000021  0.100618
# HIV+              2.208176e-10  0.075435  0.817757
# HIV-              1.076916e-14  0.000048  0.188027
# Primigravid HIV-  5.633272e-12  0.006554  0.748217

# %%
p_y_rdt_x
# Out:
#                              1         2             3
# All ANC visits    0.000000e+00  0.557997  0.000000e+00
# Primigravidae     0.000000e+00  0.568349  0.000000e+00
# Multigravidae     3.353996e-06  0.008799  2.677630e-07
# HIV+              0.000000e+00  0.995386  3.493851e-05
# HIV-              0.000000e+00  0.260473  1.940259e-11
# Primigravid HIV-  3.397282e-14  0.778398  9.762191e-11

# %%
sig_cross_rdt = {}
p_cross_rdt = {}
for y in years:
    sig_cross_rdt[str(y)] = {}
    p_cross_rdt[str(y)] = {}
    mask = cross_err_rdt[str(y)]**2 > 0
    sig_cross_rdt[str(y)]['children 2-10'] = errors.chi_square(cross_2pcf_rdt[str(y)][mask], cross_err_rdt[str(y)][mask], \
                                                           0*cross_2pcf_rdt[str(y)][mask], 0*cross_err_rdt[str(y)][mask])
    p_cross_rdt[str(y)]['children 2-10'] = chi22p(sig_cross_rdt[str(y)]['children 2-10']*bins, bins)
sig_cross_rdt = pd.DataFrame(sig_cross_rdt)
p_cross_rdt = pd.DataFrame(p_cross_rdt)

# %%
sig_cross = {}
p_cross = {}
for y in years:
    sig_cross[str(y)] = {}
    p_cross[str(y)] = {}
    mask = cross_err[str(y)]**2 > 0
    sig_cross[str(y)]['children 2-10'] = errors.chi_square(cross_2pcf[str(y)][mask], cross_err[str(y)][mask], \
                                                           0*cross_2pcf[str(y)][mask], 0*cross_err[str(y)][mask])
    p_cross[str(y)]['children 2-10'] = chi22p(sig_cross[str(y)]['children 2-10']*bins, bins)
sig_cross = pd.DataFrame(sig_cross)
p_cross = pd.DataFrame(p_cross)



sig_y = {}
p_y = {}
for y in years:
    sig_y[str(y)] = {}
    p_y[str(y)] = {}
    for s in mipmon_selection:
        mask = mip_err_y[str(y)][s]**2 > 0
        sig_y[str(y)][s] = errors.chi_square(mip_2pcf_y[str(y)][s][mask], mip_err_y[str(y)][s][mask], \
                                             0*mip_2pcf_y[str(y)][s][mask], 0*mip_err_y[str(y)][s][mask])
        p_y[str(y)][s] = chi22p(sig_y[str(y)][s]*bins, bins)
sig_y = pd.DataFrame(sig_y)
p_y = pd.DataFrame(p_y)



sig_y_rdt = {}
p_y_rdt = {}
for y in years:
    sig_y_rdt[str(y)] = {}
    p_y_rdt[str(y)] = {}
    for s in mipmon_selection:
        mask = mip_err_y_rdt[str(y)][s]**2 > 0
        sig_y_rdt[str(y)][s] = errors.chi_square(mip_2pcf_y_rdt[str(y)][s][mask], mip_err_y_rdt[str(y)][s][mask], \
                                             0*mip_2pcf_y_rdt[str(y)][s][mask], 0*mip_err_y_rdt[str(y)][s][mask])
        p_y_rdt[str(y)][s] = chi22p(sig_y_rdt[str(y)][s]*bins, bins)
sig_y_rdt = pd.DataFrame(sig_y_rdt)
p_y_rdt = pd.DataFrame(p_y_rdt)

# %%
sig_cross_ss = {}
for y in years:
    sig_cross_ss[str(y)] = {}
    mask = cross_err_ss[str(y)]**2 > 0
    sig_cross_ss[str(y)]['children 2-10'] = errors.chi_square(cross_2pcf_ss[str(y)][mask], cross_err_ss[str(y)][mask], \
                                                           0*cross_2pcf_ss[str(y)][mask], 0*cross_err_ss[str(y)][mask])
sig_cross_ss = pd.DataFrame(sig_cross_ss)

sig_y_ss = {}
for y in years:
    sig_y_ss[str(y)] = {}
    for s in mipmon_selection:
        mask = mip_err_y_ss[str(y)][s]**2 > 0
        sig_y_ss[str(y)][s] = errors.chi_square(mip_2pcf_y_ss[str(y)][s][mask], mip_err_y_ss[str(y)][s][mask], \
                                             0*mip_2pcf_y_ss[str(y)][s][mask], 0*mip_err_y_ss[str(y)][s][mask])
sig_y_ss = pd.DataFrame(sig_y_ss)

# %%
sig_tw90 = {}
for y in years:
    sig_tw90[str(y)] = {}
    for s in mipmon_selection:
        mask = mip_err_tw90[str(y)][s]**2 > 0
        sig_tw90[str(y)][s] = errors.chi_square(mip_2pcf_tw90[str(y)][s][mask], mip_err_tw90[str(y)][s][mask], \
                                                0*mip_2pcf_tw90[str(y)][s][mask], 0*mip_err_tw90[str(y)][s][mask])
sig_tw90 = pd.DataFrame(sig_tw90)

sig_tw180 = {}
for y in years:
    sig_tw180[str(y)] = {}
    for s in mipmon_selection:
        mask = mip_err_tw180[str(y)][s]**2 > 0
        sig_tw180[str(y)][s] = errors.chi_square(mip_2pcf_tw180[str(y)][s][mask], mip_err_tw180[str(y)][s][mask], \
                                                 0*mip_2pcf_tw180[str(y)][s][mask], 0*mip_err_tw180[str(y)][s][mask])
sig_tw180 = pd.DataFrame(sig_tw180)

# %%
p_cross_rdt
# Out:
#                  1    2         3
# children 2-10  0.0  0.0  0.000031

# %%
sig_cross_rdt
# Out:
#                        1           2         3
# children 2-10  18.802514  202.647198  3.851396

# %%
p_cross
# Out:
#                           1    2         3
# children 2-10  5.822678e-07  0.0  0.326927

# %%
sig_cross
# Out:
#                       1         2         3
# children 2-10  4.815188  37.71543  1.140391

# %%
p_y
# Out:
#                          1             2         3
# All prenatal  0.000000e+00  7.425964e-09  0.072841
# Primigravid   1.523559e-11  3.144196e-11  0.048554
# Multigravid   3.167466e-12  8.072862e-03  0.203563

# %%
sig_y
# Out:
#                       1         2         3
# All prenatal  15.432755  5.835035  1.706948
# Primigravid    7.239789  7.077256  1.840170
# Multigravid    7.590718  2.382707  1.337291

# %%
p_y_rdt
# Out:
#                          1         2         3
# All prenatal  9.967582e-13  0.013099  0.093159
# Primigravid   0.000000e+00  0.013788  0.211902
# Multigravid   2.351250e-03  0.487423  0.155902

# %%
sig_y_rdt
# Out:
#                       1         2         3
# All prenatal   7.847876  2.242071  1.623280
# Primigravid   21.637963  2.226969  1.321493
# Multigravid    2.728017  0.947794  1.439078

# %%
sig_cross_ss
# Out:
#                      1          2         3
# children 2-10  0.20073  143.64524  0.885868

# %%
sig_y_ss
# Out:
#                       1         2         3
# All prenatal   7.269804  1.426875  0.782205
# Primigravid    1.970940  1.615527  0.741699
# Multigravid   12.304457  0.389132  0.610889

# %%
sig_tw90
# Out:
#                   2017      2018      2019
# All prenatal  5.162776  2.104649  2.112842
# Primigravid   3.957508  0.499518  0.919605
# Multigravid   2.867321  1.724694  1.972814
# HIV+          3.936779  0.919249  1.286679
# HIV-          3.529183  2.471693  3.233597

# %%
sig_tw180
# Out:
#                   2017      2018      2019
# All prenatal  6.161764  1.363054  4.360147
# Primigravid   4.748570  0.509338  1.425571
# Multigravid   4.844743  1.260580  5.078692
# HIV+          8.025663  1.470518  1.135401
# HIV-          6.386925  4.273341  6.618839

# %% [markdown]
# # TO DO:
#
# Repeat analysis for RDT

# %% [markdown]
# ###  Potential complementary descriptive analysis (TBD):
#
# We will measure the number of samples as a function of the geographical distance from the closest health centre from the three centres of the MiPMon project. This will be done for the different populations of pregnant women in order to identify possible differences in the geographic distribution of them. The same will be done for children 2-10 to compare how differently they are distributed compared to pregnant women. This will potentially help to refine the interpretation of the 2PCF results and the different statistical power for the different populations and scales.
