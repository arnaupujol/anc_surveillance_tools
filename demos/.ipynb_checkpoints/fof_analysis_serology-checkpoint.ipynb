# %% [markdown]
# # FOF analysis

# %% [markdown]
# This notebook aims to show the main hotspot analysis using ANC serological data

# %% [markdown]
# ## Importing modules

# %%
import numpy as np
import pandas as pd
import geopandas
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib import cm
import contextily as ctx
from spatial_tools import fof, clustering
from pregmal_pytools import spatial_utils

# %% [markdown]
# ## Import data

# %%
mipmon, cross, cross210, antigens = spatial_utils.import_spatial_data()
# Out:
# /home/isglobal.lan/apujol/anaconda3/envs/py38/lib/python3.8/site-packages/geopandas/geodataframe.py:1443: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /home/isglobal.lan/apujol/anaconda3/envs/py38/lib/python3.8/site-packages/geopandas/geodataframe.py:1443: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# ...

# %% [markdown]
# ## Defining masks and other definitions

# %%
#MiPMon masks
has_geo_mip = mipmon['latitude'].notnull()&mipmon['longitude'].notnull()
has_pcr_mip = mipmon['pcrpos'].notnull()&has_geo_mip
mip_pcrpos = mipmon['pcrpos'] == 1
mip_pcrneg = mipmon['pcrpos'] == 0
mip_rdtpos = mipmon['density'] >= 100
mip_rdtneg = mipmon['density'] < 100
prenatal = (mipmon['visit'] == 'PN')&has_pcr_mip

#Define masks for MiPMon data
mipmon_pn = prenatal&has_geo_mip
mipmon_pg = mipmon_pn&(mipmon['gestnum'] == 1)
mipmon_sg = mipmon_pn&(mipmon['gestnum'] == 2)
mipmon_12g = mipmon_pn&(mipmon['gestnum'] <= 2)
mipmon_mg = mipmon_pn&(mipmon['gestnum'] > 1)
mipmon_3g = mipmon_pn&(mipmon['gestnum'] > 2)
mipmon_hiv_pos = mipmon_pn&(mipmon['hiv'] == 'HIV+')
mipmon_hiv_neg = mipmon_pn&(mipmon['hiv'] == 'HIV-')
mipmon_pg_hiv_pos = mipmon_pg&mipmon_hiv_pos
mipmon_pg_hiv_neg = mipmon_pg&mipmon_hiv_neg

mipmon_selection = {
    'All prenatal' : mipmon_pn,
    'Primigravid' : mipmon_pg,
    #'Secundigravid' : mipmon_sg,
    #'1-2gravid' : mipmon_12g,
    #'>2gravid' : mipmon_3g,
    'Multigravid' : mipmon_mg,
    'HIV+' : mipmon_hiv_pos,
    'HIV-' : mipmon_hiv_neg,
    #'PG HIV+' : mipmon_pg_hiv_pos,
    #'Primigravid HIV-' : mipmon_pg_hiv_neg,
}

#Cross masks
has_geo_cross = cross['lat'].notnull()&cross['lng'].notnull()
has_pcr_cross = cross['pospcr'].notnull()&has_geo_cross
has_rdt_cross = cross['rdt'].notnull()&has_geo_cross
cross_pcrpos = cross['pospcr'] == 1
cross_pcrneg = cross['pospcr'] == 0
cross_rdtpos = cross['rdt'] == 1
cross_rdtneg = cross['rdt'] == 0

has_geo_cross210 = cross210['lat'].notnull()&cross210['lng'].notnull()
has_pcr_cross210 = cross210['pospcr'].notnull()&has_geo_cross210
has_rdt_cross210 = cross210['rdt'].notnull()&has_geo_cross210
cross210_pcrpos = cross210['pospcr'] == 1
cross210_pcrneg = cross210['pospcr'] == 0
cross210_rdtpos = cross210['rdt'] == 1
cross210_rdtneg = cross210['rdt'] == 0

#Defining x and y coordinates
mipmon = mipmon.to_crs(3857)
geo_mask = (mipmon['latitude'].notnull())&(mipmon['longitude'].notnull())
mipmon['x'] = mipmon['geometry'][geo_mask].apply(lambda p: p.x)
mipmon['y'] = mipmon['geometry'][geo_mask].apply(lambda p: p.y)
geo_mask = (cross210['lat'].notnull())&(cross210['lng'].notnull())
cross210['x'] = cross210['geometry'][geo_mask].apply(lambda p: p.x)
cross210['y'] = cross210['geometry'][geo_mask].apply(lambda p: p.y)
geo_mask = (cross['lat'].notnull())&(cross['lng'].notnull())
cross['x'] = cross['geometry'][geo_mask].apply(lambda p: p.x)
cross['y'] = cross['geometry'][geo_mask].apply(lambda p: p.y)

#Define names and positions of main locations
list_locs = {
    'Manhica' : [32.80722050, -25.40221980], #From Pau Cisteró excel
    'Maputo' : [32.576388888888889, -25.915277666666],
    #'Montepuez' : [38.99972150, -13.12555980], #From Pau Cisteró excel
    'Chokwe' : [33.005166666666666667, -24.5252777777777777],
    #'Moatize' : [33.73333040, -16.11666620], #From Pau Cisteró excel
    #'Dondo' : [34.75, -19.6166666666666667],
    'Magude' : [32.64216410, -25.02049992], #From Pau Cisteró excel
    'Ilha Josina' : [32.92210000, -25.09330000], #From Pau Cisteró excel
    'Xinavane' : [32.791885, -25.048534],
    'Panjane' : [32.352430, -24.899469],
    'Motaze' : [32.860569, -24.810357],
    'Mapulanguene' : [32.081602, -24.491015],
    'Taninga' : [32.825796, -25.182094],
    'Palmeira' : [32.869766, -25.261457],
    #'Massinga' : [35.37405260,-23.32666250], #From Pau Cisteró excel
    #'Mopeia' : [35.71338490, -17.97391000], #From Pau Cisteró excel
    }

locations = pd.DataFrame({'location' : [i for i in list_locs], 'longitude': [list_locs[i][0] for i in list_locs], 'latitude': [list_locs[i][1] for i in list_locs]})
locations = geopandas.GeoDataFrame(locations, geometry = geopandas.points_from_xy(locations['longitude'], locations['latitude']))
locations = locations.set_crs(epsg=4326)
locations = locations.to_crs(epsg=3857)

years = [1, 2, 3]
# Out:
# /home/isglobal.lan/apujol/anaconda3/envs/py38/lib/python3.8/site-packages/geopandas/geodataframe.py:1443: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /home/isglobal.lan/apujol/anaconda3/envs/py38/lib/python3.8/site-packages/geopandas/geodataframe.py:1443: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)

# %% [markdown]
# ## Application of the hotspot detection algorithm:

# %% [markdown]
# ### Overplotting hotspots from different data sources

# %%
mipmon['FMM_DBL3-4'] = mipmon['FMM_DBL34']

# %% [markdown]
# # plots for paper and poster

# %%
ylims = [-2.93*10**6, -2.86*10**6]
xlims = [3.6*10**6, 3.68*10**6]

# %%
cutoff = 'FMM'
antigens_list = ['MSP1', 'HSP40', 'Etramp', 'ACS5', \
                 'EBA175', 'PfTramp', 'GEXP18', \
                 'PfRH2', 'PfRH5', 'P1', 'P39', \
                 'P8', 'PD', 'DBL3-4', 'All peptides']

#antigens_list = ['DBL34', \
#                 'Etramp', 'ACS5', 'MSP1', 'P39', \
#                 'EBA175', 'PfTramp', 'peptides_pos']

min_size_fof = 5
min_pr_fof = 0
max_p_fof = .05
linking_d = 1000
print("---------- Linking distance =", linking_d, " ----------")

print("----------------------------------------")
time_width = None
print("------------ Time window:", time_width, " -------------")
selection = 'All prenatal'


markers_y = ['o', 's', '^']
colors_a = [cm.turbo(i/len(antigens_list)) for i in range(len(antigens_list))]
antigens_list.append('qPCR')
colors_a.append('k')

ax = mipmon.plot(markersize = 0, figsize = [8,8], alpha = 0)
ctx.add_basemap(ax, source=ctx.providers.OpenStreetMap.Mapnik, crs = mipmon.crs)
for i, a in enumerate(antigens_list):
    if a == 'qPCR':
        test_name = 'pcrpos'
    else:
        test_name = cutoff + '_' + a
    mip_sel = mipmon_selection[selection]&mipmon[test_name].notnull()
    for year in years:
        mip_mask_year = mipmon['year'] == year
        
        #Define data for FOF input
        
        mipmon_positions = np.array((mipmon['x'][mip_mask_year&mip_sel], mipmon['y'][mip_mask_year&mip_sel])).T
        mipmon_test = np.array(mipmon[test_name][mip_mask_year&mip_sel])
        
        fofid_mip, mean_pr_fof_mip, pval_fof_mip, \
        fof_catalogue_mip = fof.get_fof_PR(mipmon_positions, mipmon_test, linking_d, fofid = None)
        
        mask_mip = (fof_catalogue_mip['positives']>=min_size_fof)&\
                    (fof_catalogue_mip['mean_pr']>=min_pr_fof)&\
                    (fof_catalogue_mip['p']<=max_p_fof)
        fof_catalogue_mip = fof_catalogue_mip[mask_mip]
        
        #print("Number of FOFs in " + test_name + ":", np.sum(mask_mip))
        #Mapping
        if i == 0:
            label = 'MSP1 year ' + str(year)
        elif year == 1:
            if a == 'qPCR':
                label = a
            else:
                label = test_name[4:]
        else:
            label = None
            
        fof_catalogue_mip[mask_mip].plot(ax = ax, color = colors_a[i], \
                                         markersize = 100, marker = markers_y[year - 1], \
                                         alpha = .75, label = label)

    
#locations.plot(ax = ax, color = 'k', markersize = 20)
#locations.apply(lambda x: ax.annotate(s=x.location, xy=x.loc['geometry'].coords[0]), axis=1)
plt.legend(ncol = 2, loc = 'lower left')
plt.title("Spatial distribution of hotspots")
if xlims is not None:
    plt.xlim(xlims[0], xlims[1])
if ylims is not None:
    plt.ylim(ylims[0], ylims[1])

plt.show()
# Out:
# ---------- Linking distance = 1000  ----------
# ----------------------------------------
# ------------ Time window: None  -------------
# /home/isglobal.lan/apujol/anaconda3/envs/py38/lib/python3.8/site-packages/geopandas/geodataframe.py:1415: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   result = super().__getitem__(key)
# /home/isglobal.lan/apujol/anaconda3/envs/py38/lib/python3.8/site-packages/geopandas/plotting.py:693: UserWarning: The GeoDataFrame you are attempting to plot is empty. Nothing has been displayed.
#   warnings.warn(
# /home/isglobal.lan/apujol/anaconda3/envs/py38/lib/python3.8/site-packages/geopandas/geodataframe.py:1415: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   result = super().__getitem__(key)
# /home/isglobal.lan/apujol/anaconda3/envs/py38/lib/python3.8/site-packages/geopandas/geodataframe.py:1415: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# ...

# %%
ylims_ilha = [-2.907*10**6, -2.885*10**6]
xlims_ilha = [3.661*10**6, 3.6725*10**6]

ylims_manhica = [-2.9192*10**6, -2.9182*10**6]
xlims_manhica = [3.653*10**6 +100, 3.653*10**6 +500]

ylims_magude = [-2.889*10**6, -2.880*10**6]
xlims_magude = [3.617*10**6, 3.637*10**6]

# %%
cutoff = 'FMM'
antigens_list = ['MSP1', 'HSP40', 'Etramp', 'ACS5', \
                 'EBA175', 'PfTramp', 'GEXP18', \
                 'PfRH2', 'PfRH5', 'P1', 'P39', \
                 'P8', 'PD', 'DBL3-4', 'All peptides']

#antigens_list = ['DBL34', \
#                 'Etramp', 'ACS5', 'MSP1', 'P39', \
#                 'EBA175', 'PfTramp', 'peptides_pos']

min_size_fof = 5
min_pr_fof = 0
max_p_fof = .05
linking_d = 1000
print("---------- Linking distance =", linking_d, " ----------")

print("----------------------------------------")
time_width = None
print("------------ Time window:", time_width, " -------------")
selection = 'All prenatal'


markers_y = ['o', 's', '^']
colors_a = [cm.turbo(i/len(antigens_list)) for i in range(len(antigens_list))]
antigens_list.append('qPCR')
colors_a.append('k')

spatial_mask = (mipmon['x'] > xlims_ilha[0])&(mipmon['x'] < xlims_ilha[1])&\
                (mipmon['y'] > ylims_ilha[0])&(mipmon['y'] < ylims_ilha[1])
ax = mipmon[spatial_mask].plot(markersize = 0, figsize = [8,8], alpha = 0)
ctx.add_basemap(ax, source=ctx.providers.OpenStreetMap.Mapnik)
for i, a in enumerate(antigens_list):
    if a == 'qPCR':
        test_name = 'pcrpos'
    else:
        test_name = cutoff + '_' + a
    mip_sel = mipmon_selection[selection]&mipmon[test_name].notnull()
    for year in years:
        mip_mask_year = (mipmon['year'] == year)
        
        #Define data for FOF input
        
        mipmon_positions = np.array((mipmon['x'][mip_mask_year&mip_sel], mipmon['y'][mip_mask_year&mip_sel])).T
        mipmon_test = np.array(mipmon[test_name][mip_mask_year&mip_sel])
        
        fofid_mip, mean_pr_fof_mip, pval_fof_mip, \
        fof_catalogue_mip = fof.get_fof_PR(mipmon_positions, mipmon_test, linking_d, fofid = None)
        
        mask_mip = (fof_catalogue_mip['positives']>=min_size_fof)&\
                    (fof_catalogue_mip['mean_pr']>=min_pr_fof)&\
                    (fof_catalogue_mip['p']<=max_p_fof)
        fof_catalogue_mip = fof_catalogue_mip[mask_mip]
        
        #print("Number of FOFs in " + test_name + ":", np.sum(mask_mip))
        #Mapping
        if i == 0:
            label = 'DBL3-4 year ' + str(year)
        elif year == 1:
            if a == 'qPCR':
                label = a
            else:
                label = test_name[4:]
        else:
            label = None
            
        fof_catalogue_mip[mask_mip].plot(ax = ax, color = colors_a[i], \
                                         markersize = 100, marker = markers_y[year - 1], \
                                         alpha = .75, label = label)

#Plotting Cross-sectional hotspots in qPCR
test_name = 'pospcr'
cross_sel = cross[test_name].notnull()
for year in years:
    cross_mask_year = cross['year'] == year    
    #Define data for FOF input    
    cross_positions = np.array((cross['x'][cross_mask_year&cross_sel], cross['y'][cross_mask_year&cross_sel])).T
    cross_test = np.array(cross[test_name][cross_mask_year&cross_sel])
        
    fofid_cross, mean_pr_fof_cross, pval_fof_cross, \
    fof_catalogue_cross = fof.get_fof_PR(cross_positions, cross_test, linking_d, fofid = None)
        
    mask_cross = (fof_catalogue_cross['positives']>=min_size_fof)&\
                (fof_catalogue_cross['mean_pr']>=min_pr_fof)&\
                (fof_catalogue_cross['p']<=max_p_fof)
    fof_catalogue_cross = fof_catalogue_cross[mask_cross]
    
    print("Number of FOFs in " + test_name + ":", np.sum(mask_cross))
    #Mapping
        
    fof_catalogue_cross[mask_cross].plot(ax = ax, color = 'tab:grey', \
                                     markersize = 100, marker = markers_y[year - 1], \
                                     alpha = .75, label = 'Cross qPCR')
    
#locations.plot(ax = ax, color = 'k', markersize = 20)
#locations.apply(lambda x: ax.annotate(s=x.location, xy=x.loc['geometry'].coords[0]), axis=1)
#plt.legend(ncol = 2, loc = 'lower left')
plt.title("Spatial distribution of hotspots")
plt.ylim(ylims_ilha[0], ylims_ilha[1])
plt.xlim(xlims_ilha[0], xlims_ilha[1])
plt.show()
# Out:
# ---------- Linking distance = 1000  ----------
# ----------------------------------------
# ------------ Time window: None  -------------
# /home/isglobal.lan/apujol/anaconda3/envs/py38/lib/python3.8/site-packages/geopandas/geodataframe.py:1415: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   result = super().__getitem__(key)
# /home/isglobal.lan/apujol/anaconda3/envs/py38/lib/python3.8/site-packages/geopandas/plotting.py:693: UserWarning: The GeoDataFrame you are attempting to plot is empty. Nothing has been displayed.
#   warnings.warn(
# /home/isglobal.lan/apujol/anaconda3/envs/py38/lib/python3.8/site-packages/geopandas/geodataframe.py:1415: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   result = super().__getitem__(key)
# /home/isglobal.lan/apujol/anaconda3/envs/py38/lib/python3.8/site-packages/geopandas/geodataframe.py:1415: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# ...

# %%
cutoff = 'FMM'
antigens_list = ['MSP1', 'HSP40', 'Etramp', 'ACS5', \
                 'EBA175', 'PfTramp', 'GEXP18', \
                 'PfRH2', 'PfRH5', 'P1', 'P39', \
                 'P8', 'PD', 'DBL3-4', 'All peptides']

#antigens_list = ['DBL34', \
#                 'Etramp', 'ACS5', 'MSP1', 'P39', \
#                 'EBA175', 'PfTramp', 'peptides_pos']

min_size_fof = 5
min_pr_fof = 0
max_p_fof = .05
linking_d = 1000
print("---------- Linking distance =", linking_d, " ----------")

print("----------------------------------------")
time_width = None
print("------------ Time window:", time_width, " -------------")
selection = 'All prenatal'


markers_y = ['o', 's', '^']
colors_a = [cm.turbo(i/len(antigens_list)) for i in range(len(antigens_list))]
antigens_list.append('qPCR')
colors_a.append('k')

spatial_mask = (mipmon['x'] > xlims_manhica[0])&(mipmon['x'] < xlims_manhica[1])&\
                (mipmon['y'] > ylims_manhica[0])&(mipmon['y'] < ylims_manhica[1])
ax = mipmon[spatial_mask].plot(markersize = 0, figsize = [8,8], alpha = 0)
ctx.add_basemap(ax, source=ctx.providers.OpenStreetMap.Mapnik)
for i, a in enumerate(antigens_list):
    if a == 'qPCR':
        test_name = 'pcrpos'
    else:
        test_name = cutoff + '_' + a
    mip_sel = mipmon_selection[selection]&mipmon[test_name].notnull()
    for year in years:
        mip_mask_year = mipmon['year'] == year
        
        #Define data for FOF input
        
        mipmon_positions = np.array((mipmon['x'][mip_mask_year&mip_sel], mipmon['y'][mip_mask_year&mip_sel])).T
        mipmon_test = np.array(mipmon[test_name][mip_mask_year&mip_sel])
        
        fofid_mip, mean_pr_fof_mip, pval_fof_mip, \
        fof_catalogue_mip = fof.get_fof_PR(mipmon_positions, mipmon_test, linking_d, fofid = None)
        
        mask_mip = (fof_catalogue_mip['positives']>=min_size_fof)&\
                    (fof_catalogue_mip['mean_pr']>=min_pr_fof)&\
                    (fof_catalogue_mip['p']<=max_p_fof)
        fof_catalogue_mip = fof_catalogue_mip[mask_mip]
        
        #print("Number of FOFs in " + test_name + ":", np.sum(mask_mip))
        #Mapping
        if i == 0:
            label = 'DBL3-4 year ' + str(year)
        elif year == 1:
            if a == 'qPCR':
                label = a
            else:
                label = test_name[4:]
        else:
            label = None
            
        fof_catalogue_mip[mask_mip].plot(ax = ax, color = colors_a[i], \
                                         markersize = 100, marker = markers_y[year - 1], \
                                         alpha = .75, label = label)

#Plotting Cross-sectional hotspots in qPCR
test_name = 'pospcr'
cross_sel = cross[test_name].notnull()
for year in years:
    cross_mask_year = cross['year'] == year    
    #Define data for FOF input    
    cross_positions = np.array((cross['x'][cross_mask_year&cross_sel], cross['y'][cross_mask_year&cross_sel])).T
    cross_test = np.array(cross[test_name][cross_mask_year&cross_sel])
        
    fofid_cross, mean_pr_fof_cross, pval_fof_cross, \
    fof_catalogue_cross = fof.get_fof_PR(cross_positions, cross_test, linking_d, fofid = None)
        
    mask_cross = (fof_catalogue_cross['positives']>=min_size_fof)&\
                (fof_catalogue_cross['mean_pr']>=min_pr_fof)&\
                (fof_catalogue_cross['p']<=max_p_fof)
    fof_catalogue_cross = fof_catalogue_cross[mask_cross]
    
    print("Number of FOFs in " + test_name + ":", np.sum(mask_cross))
    #Mapping
        
    fof_catalogue_cross[mask_cross].plot(ax = ax, color = 'tab:grey', \
                                     markersize = 100, marker = markers_y[year - 1], \
                                     alpha = .75, label = 'Cross qPCR')
    
#locations.plot(ax = ax, color = 'k', markersize = 20)
#locations.apply(lambda x: ax.annotate(s=x.location, xy=x.loc['geometry'].coords[0]), axis=1)
#plt.legend(ncol = 2, loc = 'lower left')
plt.title("Spatial distribution of hotspots")
plt.ylim(ylims_manhica[0], ylims_manhica[1])
plt.xlim(xlims_manhica[0], xlims_manhica[1])
plt.show()
# Out:
# ---------- Linking distance = 1000  ----------
# ----------------------------------------
# ------------ Time window: None  -------------
# /home/isglobal.lan/apujol/anaconda3/envs/py38/lib/python3.8/site-packages/contextily/tile.py:581: UserWarning: The inferred zoom level of 22 is not valid for the current tile provider (valid zooms: 0 - 19).
#   warnings.warn(msg)
# /home/isglobal.lan/apujol/anaconda3/envs/py38/lib/python3.8/site-packages/geopandas/geodataframe.py:1415: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   result = super().__getitem__(key)
# /home/isglobal.lan/apujol/anaconda3/envs/py38/lib/python3.8/site-packages/geopandas/plotting.py:693: UserWarning: The GeoDataFrame you are attempting to plot is empty. Nothing has been displayed.
#   warnings.warn(
# /home/isglobal.lan/apujol/anaconda3/envs/py38/lib/python3.8/site-packages/geopandas/geodataframe.py:1415: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# ...

# %%
cutoff = 'FMM'
antigens_list = ['MSP1', 'HSP40', 'Etramp', 'ACS5', \
                 'EBA175', 'PfTramp', 'GEXP18', \
                 'PfRH2', 'PfRH5', 'P1', 'P39', \
                 'P8', 'PD', 'DBL3-4', 'All peptides']

#antigens_list = ['DBL34', \
#                 'Etramp', 'ACS5', 'MSP1', 'P39', \
#                 'EBA175', 'PfTramp', 'peptides_pos']

min_size_fof = 5
min_pr_fof = 0
max_p_fof = .05
linking_d = 1000
print("---------- Linking distance =", linking_d, " ----------")

print("----------------------------------------")
time_width = None
print("------------ Time window:", time_width, " -------------")
selection = 'All prenatal'


markers_y = ['o', 's', '^']
colors_a = [cm.turbo(i/len(antigens_list)) for i in range(len(antigens_list))]
antigens_list.append('qPCR')
colors_a.append('k')

spatial_mask = (mipmon['x'] > xlims_magude[0])&(mipmon['x'] < xlims_magude[1])&\
                (mipmon['y'] > ylims_magude[0])&(mipmon['y'] < ylims_magude[1])
ax = mipmon[spatial_mask].plot(markersize = 0, figsize = [8,8], alpha = 0)
ctx.add_basemap(ax, source=ctx.providers.OpenStreetMap.Mapnik)
for i, a in enumerate(antigens_list):
    if a == 'qPCR':
        test_name = 'pcrpos'
    else:
        test_name = cutoff + '_' + a
    mip_sel = mipmon_selection[selection]&mipmon[test_name].notnull()
    for year in years:
        mip_mask_year = mipmon['year'] == year
        
        #Define data for FOF input
        
        mipmon_positions = np.array((mipmon['x'][mip_mask_year&mip_sel], mipmon['y'][mip_mask_year&mip_sel])).T
        mipmon_test = np.array(mipmon[test_name][mip_mask_year&mip_sel])
        
        fofid_mip, mean_pr_fof_mip, pval_fof_mip, \
        fof_catalogue_mip = fof.get_fof_PR(mipmon_positions, mipmon_test, linking_d, fofid = None)
        
        mask_mip = (fof_catalogue_mip['positives']>=min_size_fof)&\
                    (fof_catalogue_mip['mean_pr']>=min_pr_fof)&\
                    (fof_catalogue_mip['p']<=max_p_fof)
        fof_catalogue_mip = fof_catalogue_mip[mask_mip]
        
        #print("Number of FOFs in " + test_name + ":", np.sum(mask_mip))
        #Mapping
        if i == 0:
            label = 'DBL3-4 year ' + str(year)
        elif year == 1:
            if a == 'qPCR':
                label = a
            else:
                label = test_name[4:]
        else:
            label = None
            
        fof_catalogue_mip[mask_mip].plot(ax = ax, color = colors_a[i], \
                                         markersize = 100, marker = markers_y[year - 1], \
                                         alpha = .75, label = label)

#Plotting Cross-sectional hotspots in qPCR
test_name = 'pospcr'
cross_sel = cross[test_name].notnull()
for year in years:
    cross_mask_year = cross['year'] == year    
    #Define data for FOF input    
    cross_positions = np.array((cross['x'][cross_mask_year&cross_sel], cross['y'][cross_mask_year&cross_sel])).T
    cross_test = np.array(cross[test_name][cross_mask_year&cross_sel])
        
    fofid_cross, mean_pr_fof_cross, pval_fof_cross, \
    fof_catalogue_cross = fof.get_fof_PR(cross_positions, cross_test, linking_d, fofid = None)
        
    mask_cross = (fof_catalogue_cross['positives']>=min_size_fof)&\
                (fof_catalogue_cross['mean_pr']>=min_pr_fof)&\
                (fof_catalogue_cross['p']<=max_p_fof)
    fof_catalogue_cross = fof_catalogue_cross[mask_cross]
    
    print("Number of FOFs in " + test_name + ":", np.sum(mask_cross))
    #Mapping
        
    fof_catalogue_cross[mask_cross].plot(ax = ax, color = 'tab:grey', \
                                     markersize = 100, marker = markers_y[year - 1], \
                                     alpha = .75, label = 'Cross qPCR')
    
#locations.plot(ax = ax, color = 'k', markersize = 20)
#locations.apply(lambda x: ax.annotate(s=x.location, xy=x.loc['geometry'].coords[0]), axis=1)
#plt.legend(ncol = 2, loc = 'lower left')
plt.title("Spatial distribution of hotspots")
plt.ylim(ylims_magude[0], ylims_magude[1])
plt.xlim(xlims_magude[0], xlims_magude[1])
plt.show()
# Out:
# ---------- Linking distance = 1000  ----------
# ----------------------------------------
# ------------ Time window: None  -------------
# /home/isglobal.lan/apujol/anaconda3/envs/py38/lib/python3.8/site-packages/geopandas/geodataframe.py:1415: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   result = super().__getitem__(key)
# /home/isglobal.lan/apujol/anaconda3/envs/py38/lib/python3.8/site-packages/geopandas/plotting.py:693: UserWarning: The GeoDataFrame you are attempting to plot is empty. Nothing has been displayed.
#   warnings.warn(
# /home/isglobal.lan/apujol/anaconda3/envs/py38/lib/python3.8/site-packages/geopandas/geodataframe.py:1415: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   result = super().__getitem__(key)
# /home/isglobal.lan/apujol/anaconda3/envs/py38/lib/python3.8/site-packages/geopandas/geodataframe.py:1415: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# ...
